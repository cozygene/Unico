# %%
library("ggplot2")
library("ggpubr")
library("scales")
library("reshape2")
library("ggpattern")

# mutation plot 
library("pracma")
library("ggplot2")
library("gghalves")
library("ggbeeswarm")

set.seed(2023)

# %%
metric = "MCC" # choose from "MCC" "F1"

# %%
res.dir    = "../Result/Methylation/Consistency/XY"
figure.dir = "../Figure/EWAS-Consistency/"

if (!file.exists(figure.dir)){dir.create(file.path(figure.dir),recursive = T)}
if (!file.exists(res.dir)){print("missing result")}

print(figure.dir)
print(res.dir)
# Out:
# [1] "../Figure/EWAS-Consistency/"
# [1] "../Result/Methylation/Consistency/XY"

# %% [markdown]
# # Load

# %%
age.meta.mats    = readRDS(file.path(res.dir, paste0("age.meta.mats.", metric, ".rds")))
gender.meta.mats = readRDS(file.path(res.dir, paste0("gender.meta.mats.", metric, ".rds")))

# %%
# add in bMIND for gender
gender.bMIND.meta.mats = readRDS(file.path(res.dir, "gender.bMIND.meta.mats.MCC.rds"))
gender.meta.mats = c(gender.meta.mats, gender.bMIND.meta.mats)
# for age just fill with NA
for (bmind.name in names(gender.bMIND.meta.mats)){   
    age.meta.mats[[bmind.name]] = matrix(NA, 4, 4)
    rownames(age.meta.mats[[bmind.name]]) = c("liu", "hannon1", "hannon2", "hannum")
    colnames(age.meta.mats[[bmind.name]]) = c("liu", "hannon1", "hannon2", "hannum")
}

# %%
gender.meta.mats
# Out:
# $TCAx.parametric.full.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8593750 0.8524590 0.8636364
# hannum  0.9512195 1.0000000 0.9487179 0.8979592
# hannon1 0.9879518 0.9230769 1.0000000 0.9642857
# hannon2 0.9714286 0.8437500 0.9600000 1.0000000
#
# $TCAx.parametric.full.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8615543 0.6658668 0.7684391
# hannum  0.7681401 1.0000000 0.5019685 0.6602779
# hannon1 0.3381806 0.2952929 1.0000000 0.9065187
# hannon2 0.3150956 0.2834503 0.6588235 1.0000000
#
# $TCAx.parametric.X2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9285714 0.8807339 0.9090909
# hannum  0.9629630 1.0000000 0.9090909 0.9200000
# hannon1 0.9870130 0.9473684 1.0000000 0.9411765
# hannon2 0.9552239 0.9180328 0.9729730 1.0000000
#
# $TCAx.parametric.X2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8763172 0.6583443 0.7458065
# hannum  0.7742782 1.0000000 0.4880083 0.6449237
# hannon1 0.3613232 0.3225532 1.0000000 0.9057554
# hannon2 0.3091413 0.3064067 0.6747788 1.0000000
#
# $TCAx.parametric.Q2.marginal
#              liu    hannum   hannon1   hannon2
# liu     1.000000 0.9333333 0.9215686 0.8974359
# hannum  0.974359 1.0000000 0.9600000 0.9583333
# hannon1 1.000000 0.9253731 1.0000000 0.9166667
# hannon2 0.937500 0.8571429 0.9230769 1.0000000
#
# $TCAx.parametric.Q2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8779070 0.6738690 0.7566515
# hannum  0.7829246 1.0000000 0.5112060 0.6593407
# hannon1 0.3377432 0.3036893 1.0000000 0.9096652
# hannon2 0.3014671 0.2835785 0.6433647 1.0000000
#
# $TCAx.parametric.XQ2.marginal
#              liu    hannum   hannon1   hannon2
# liu     1.000000 0.9189189 0.9056604 0.8205128
# hannum  0.902439 1.0000000 0.9135802 0.8679245
# hannon1 0.972973 0.9166667 1.0000000 0.9583333
# hannon2 0.937500 0.8928571 0.9393939 1.0000000
#
# $TCAx.parametric.XQ2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8924791 0.6626747 0.7437908
# hannum  0.7689625 1.0000000 0.4871001 0.6248694
# hannon1 0.3439441 0.3064327 1.0000000 0.8923280
# hannon2 0.3067318 0.2944751 0.6708696 1.0000000
#
# $TCAx.parametric.X2Q2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9090909 0.8910891 0.9117647
# hannum  0.9629630 1.0000000 0.9350649 0.9361702
# hannon1 1.0000000 0.9275362 1.0000000 0.9565217
# hannon2 0.9677419 0.9285714 0.9846154 1.0000000
#
# $TCAx.parametric.X2Q2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8916409 0.6617647 0.7489301
# hannum  0.7742243 1.0000000 0.5000000 0.6500868
# hannon1 0.3720491 0.3386792 1.0000000 0.9100318
# hannon2 0.3003310 0.3059319 0.6642617 1.0000000
#
# $TCA.parametric.full.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.6986301 0.8030303 0.8125000
# hannum  0.9024390 1.0000000 0.9487179 0.8936170
# hannon1 0.9500000 0.9066667 1.0000000 0.9615385
# hannon2 0.9859155 0.8666667 0.9428571 1.0000000
#
# $TCA.parametric.full.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8364871 0.6781545 0.7873016
# hannum  0.7702866 1.0000000 0.5009506 0.6682135
# hannon1 0.3422967 0.2876361 1.0000000 0.9006867
# hannon2 0.3285745 0.2962637 0.6659744 1.0000000
#
# $TCA.parametric.X2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9026549 0.9009009 0.9135802
# hannum  0.9736842 1.0000000 0.9487179 0.8800000
# hannon1 0.9866667 0.9600000 1.0000000 0.9787234
# hannon2 0.9855072 0.9508197 0.9859155 1.0000000
#
# $TCA.parametric.X2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8686649 0.6641075 0.7570621
# hannum  0.7718711 1.0000000 0.4919679 0.6448363
# hannon1 0.3689086 0.3234698 1.0000000 0.8950427
# hannon2 0.3199785 0.3138211 0.6708505 1.0000000
#
# $TCA.parametric.Q2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8130081 0.8928571 0.8750000
# hannum  0.9367089 1.0000000 0.9589041 0.9361702
# hannon1 0.9855072 0.9253731 1.0000000 0.9583333
# hannon2 0.8985507 0.8070175 0.9014085 1.0000000
#
# $TCA.parametric.Q2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8704018 0.6888021 0.7821720
# hannum  0.7825696 1.0000000 0.5264249 0.6788247
# hannon1 0.3446043 0.3055255 1.0000000 0.8987758
# hannon2 0.3126177 0.2981993 0.6589398 1.0000000
#
# $TCA.parametric.XQ2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9074074 0.9174312 0.8717949
# hannum  0.9638554 1.0000000 0.9500000 0.9166667
# hannon1 0.9647059 0.9176471 1.0000000 0.9642857
# hannon2 0.9315068 0.8000000 0.9066667 1.0000000
#
# $TCA.parametric.XQ2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8814898 0.6807388 0.7595593
# hannum  0.7841601 1.0000000 0.5144628 0.6580712
# hannon1 0.3592767 0.3174603 1.0000000 0.8909152
# hannon2 0.3152232 0.3018351 0.6686864 1.0000000
#
# $TCA.parametric.X2Q2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9400000 0.9072165 0.9230769
# hannum  0.9600000 1.0000000 0.9589041 0.9545455
# hannon1 0.9696970 0.9090909 1.0000000 0.9777778
# hannon2 0.9818182 0.9019608 1.0000000 1.0000000
#
# $TCA.parametric.X2Q2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8854680 0.6671470 0.7446809
# hannum  0.7750473 1.0000000 0.5127636 0.6651835
# hannon1 0.3613369 0.3403493 1.0000000 0.9029568
# hannon2 0.2984802 0.3119155 0.6749940 1.0000000
#
# $CellDMC.parametric.full.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.2337165 0.3929825 0.4790419
# hannum  0.7722772 1.0000000 0.9870130 0.9361702
# hannon1 0.8035714 0.9195402 1.0000000 0.9090909
# hannon2 0.8095238 0.8615385 0.9333333 1.0000000
#
# $CellDMC.parametric.full.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.7233065 0.5917603 0.7295539
# hannum  0.7959737 1.0000000 0.4974335 0.6721088
# hannon1 0.3212016 0.2638725 1.0000000 0.9102750
# hannon2 0.3075752 0.2714539 0.6542751 1.0000000
#
# $CellDMC.parametric.X2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8549618 0.8750000 0.8421053
# hannum  0.9662921 1.0000000 0.9534884 0.9285714
# hannon1 1.0000000 0.9534884 1.0000000 0.9696970
# hannon2 0.9565217 0.9032258 0.9736842 1.0000000
#
# $CellDMC.parametric.X2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8545455 0.6133638 0.7222832
# hannum  0.7911290 1.0000000 0.4802343 0.6474609
# hannon1 0.3220647 0.2956204 1.0000000 0.9095907
# hannon2 0.3004105 0.2927543 0.6774008 1.0000000
#
# $Baseline.parametric.full.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8490836 0.6295515 0.7585427
# hannum  0.7434416 1.0000000 0.4938520 0.6595153
# hannon1 0.2579389 0.2413450 1.0000000 0.7781527
# hannon2 0.3001131 0.2984804 0.6247876 1.0000000
#
# $Baseline.parametric.full.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8168729 0.6034241 0.7198917
# hannum  0.7627156 1.0000000 0.4612306 0.6350851
# hannon1 0.3176471 0.2780656 1.0000000 0.8985337
# hannon2 0.3183055 0.2960799 0.6509379 1.0000000
#
# $Baseline.parametric.X2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8722521 0.6320615 0.7200000
# hannum  0.7278863 1.0000000 0.5019305 0.5994242
# hannon1 0.2770921 0.2847586 1.0000000 0.8773097
# hannon2 0.2520212 0.2475256 0.6507363 1.0000000
#
# $Baseline.parametric.X2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8504544 0.6041147 0.6989280
# hannum  0.7815426 1.0000000 0.4679067 0.6147324
# hannon1 0.3263765 0.2906423 1.0000000 0.9063823
# hannon2 0.3211930 0.3126638 0.6846744 1.0000000
#
# $bMIND.YX.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.5072961 0.4297956 0.4862360
# hannum  0.5418168 1.0000000 0.4946894 0.6676553
# hannon1 0.3686113 0.4243977 1.0000000 0.2521440
# hannon2 0.2185695 0.4252532 0.2455314 1.0000000
#
# $bMIND.XY.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.3519594 0.2500466 0.4348762
# hannum  0.5550372 1.0000000 0.4184846 0.7008141
# hannon1 0.6891426 0.7106181 1.0000000 0.8934815
# hannon2 0.1703484 0.1876777 0.1536694 1.0000000
#
# $bMIND.XY.marginal
#                liu    hannum   hannon1   hannon2
# liu     1.00000000 0.1230493 0.1021761 0.0723361
# hannum  0.13128243 1.0000000 0.2463103 0.3280305
# hannon1 0.09555681 0.2258112 1.0000000 0.1623475
# hannon2 0.08899558 0.3627778 0.2176658 1.0000000

# %% [markdown]
# # checking if significant

# %%
score1 = as.numeric(age.meta.mats$"TCAx.parametric.X2.marginal")
score1 = score1[score1!=1]

score0 = as.numeric(age.meta.mats$"TCA.parametric.full.marginal")
score0 = score0[score0!=1]

res = wilcox.test(x = score1, 
                  y = score0, 
                  alternative = "g", paired = T) # x > y one side test

# %%
res
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  score1 and score0
# V = 59, p-value = 0.0647
# alternative hypothesis: true location shift is greater than 0

# %%
score1 = as.numeric(age.meta.mats$"TCAx.parametric.X2Q2.marginal")
score1 = score1[score1!=1]

score0 = as.numeric(age.meta.mats$"TCA.parametric.full.marginal")
score0 = score0[score0!=1]

res = wilcox.test(x = score1, 
                  y = score0, 
                  alternative = "g", paired = T) # x > y one side test

# %%
res
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  score1 and score0
# V = 57, p-value = 0.08813
# alternative hypothesis: true location shift is greater than 0

# %%
score1 = as.numeric(gender.meta.mats$"TCAx.parametric.X2.marginal")
score1 = score1[score1!=1]

score0 = as.numeric(gender.meta.mats$"TCA.parametric.full.marginal")
score0 = score0[score0!=1]

res = wilcox.test(x = score1, 
                  y = score0, 
                  alternative = "g", paired = T) # x > y one side test

# %%
res
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  score1 and score0
# V = 67, p-value = 0.01343
# alternative hypothesis: true location shift is greater than 0

# %%
score1 = gender.meta.mats$"TCAx.parametric.X2Q2.marginal" 
diag(score1) = NA
score1 = as.numeric(score1)
score1 = as.numeric(score1)[!is.na(as.numeric(score1))]

score0 = gender.meta.mats$"TCA.parametric.full.marginal" 
diag(score0) = NA
score0 = as.numeric(score0)
score0 = as.numeric(score0)[!is.na(as.numeric(score0))]

res = wilcox.test(x = score1, 
                  y = score0, 
                  alternative = "g", paired = T) # x > y one side test

# %%
res
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  score1 and score0
# V = 72, p-value = 0.003418
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# # Plot

# %%
label.size = 20

# %%
F1_heatmap = function(res.meta.mat, phenotype, method.names, 
                      data.names, full.data.names,
                      legend.name = "F1 score", sub.title.name = "Mean F1", 
                      min.quantile = 0.1, max.quantile = 1, 
                      title.size = 15, label.size = 20, number.size = 5, 
                      barheight = 5, barwidth = 1, barres = 0.1, hide.x = F){


    f1_vals = c()
    mean_f1_vals = c()
    for (h in 1:length(res.meta.mat)){
        
        df = res.meta.mat[[h]][data.names, data.names]
        rownames(df) = full.data.names
        colnames(df) = full.data.names
        
        if(sum(!is.na(df)) == 0){
           
            df <- melt(df)
            colnames(df) = c("Discovery", "Validation", "Effective.F1")
            df$ignore = "Yes"
            res.meta.mat[[h]] = df
            f1_vals = c(f1_vals, df$"Effective.F1")
            mean_f1_vals[[h]] = NA
           
        }else{
           
            df <- melt(df)
            df$value = round(df$value, 2)

            colnames(df) = c("Discovery", "Validation", "Effective.F1")

            # to not show the diagnol, first make it NA, then the plotting wont show this
            df[df["Discovery"] == df["Validation"], "Effective.F1"] = NA

            # also make another column: "ignore" to explicitly indicate if we need to add stripes to show ignore 
            df$ignore = "No"
            df[df["Discovery"] == df["Validation"], "ignore"] = "Yes"

            res.meta.mat[[h]] = df
            f1_vals = c(f1_vals, df$"Effective.F1")
            mean_f1_vals[[h]] = mean(df$"Effective.F1", na.rm = T)
            
        }
    }


    f1_vals = f1_vals[!is.na(f1_vals)]
    min.f1 = quantile(f1_vals, min.quantile)
    max.f1 = quantile(f1_vals, max.quantile)
    
    plts <- vector(mode = "list", length = length(res.meta.mat))
    for (h in 1:length(method.names)){
        df = res.meta.mat[[h]]
        
        df$Effective.F1 = as.numeric(df$Effective.F1)
        # make a factor variable
        df$Discovery  <- as.factor(df$Discovery)
        df$Discovery  <- factor(df$Discovery , levels = levels(df$Discovery)[c(4,3,2,1)])

        g = ggplot(data = df, aes(x = Validation, y = Discovery, pattern = ignore, fill = Effective.F1)) +
            geom_tile(color = "black") +

            geom_tile_pattern(pattern_color = NA, pattern_fill = "black",
                              pattern_angle = 325, pattern_density = 0.25, 
                              pattern_spacing = 0.025, pattern_key_scale_factor = 1,
                              show.legend = FALSE) +
            scale_pattern_manual(values = c(Yes = "stripe", No = "none")) +

            geom_text(aes(label = Effective.F1), 
                      color = "white", size = number.size) +

            scale_fill_gradientn(colors = hcl.colors(20, "cividis"), na.value="white",
                                 limits=c(min.f1, max.f1), oob=squish, 
                                 breaks = seq(round(min.f1, 1), round(max.f1,1), barres),
                                 name = legend.name) +
            coord_fixed() + 

            ggtitle(paste0(method.names[h], "-", phenotype, 
                           "\n (", sub.title.name, ": ", round(mean_f1_vals[[h]], 2), ")"))+
            
            theme(plot.title = element_text(hjust = 0.5, size = title.size),
                  text = element_text(size=label.size, face = "bold"),
                  axis.title.x = element_blank(),#remove x axis labels
                  axis.text.x  = element_text(angle = 25, vjust = 1, hjust = 1))+
            guides(fill = guide_colourbar(barwidth = barwidth, barheight = barheight)) 



        if (h != length(method.names)){g = g + theme(legend.position="none")}
        # dont show the y axis label names
        if (h != 1){
            g = g + theme(axis.title.y  = element_blank(),
                          axis.text.y  = element_blank(),  #remove y axis labels
                          axis.ticks.y = element_blank()   #remove y axis ticks
            )}
        if(hide.x){
            g = g + theme(axis.text.x  = element_blank(), 
                          axis.ticks.x = element_blank()  #remove x axis ticks
        )}

        plts[[h]] = g +  labs(tag = " ")
    }
    return(plts)
}

# %%
############################# Aggranging them with just ggarrange(not egg::ggarrange)  ############################
consistency.gender.marg.plts = F1_heatmap(res.meta.mat = gender.meta.mats[c("bMIND.YX.marginal",
                                                                            "Baseline.parametric.X2.marginal", 
                                                                            "CellDMC.parametric.full.marginal", 
                                                                            "TCA.parametric.full.marginal", 
                                                                            "TCAx.parametric.X2.marginal")],
                                          phenotype = "Sex",
                                          method.names = c("bMIND","Baseline", "CellDMC", "TCA", "Unico"),
                                          data.names = c("liu", "hannon1", "hannon2", "hannum"),
                                          full.data.names = c("Liu et al. (n= 687)",
                                                              "Hannon et al. I (n= 675)", 
                                                              "Hannon et al. II (n= 665)",
                                                              "Hannum et al. (n= 590)"),

                                          legend.name = metric, sub.title.name = paste0("Mean ", metric), 
                                          min.quantile = 0.4, max.quantile = 1, 
                                          title.size = 15, label.size = label.size, number.size = 5, 
                                          barheight = 5, barwidth = 1, 
                                          barres = 0.1, hide.x = T)

consistency.age.marg.plts = F1_heatmap(res.meta.mat = age.meta.mats[c("bMIND.YX.marginal",
                                                                      "Baseline.parametric.X2.marginal", 
                                                                      "CellDMC.parametric.full.marginal", 
                                                                      "TCA.parametric.full.marginal", 
                                                                      "TCAx.parametric.X2.marginal")],
                                       phenotype = "Age",
                                       method.names = c("bMIND", "Baseline", "CellDMC", "TCA", "Unico"),
                                       data.names = c("liu", "hannon1", "hannon2", "hannum"),
                                       full.data.names = c("Liu et al. (n= 687)",
                                                           "Hannon et al. I (n= 675)", 
                                                           "Hannon et al. II (n= 665)",
                                                           "Hannum et al. (n= 590)"),

                                       legend.name = metric, sub.title.name = paste0("Mean ", metric), 
                                       min.quantile = 0.1, max.quantile = 0.95, 
                                       title.size = 15, label.size = label.size, number.size = 5, 
                                       barheight = 5, barwidth = 1, 
                                       barres = 0.1, hide.x = F)

# %%
consistency.gender.marg.g = egg::ggarrange(plots=consistency.gender.marg.plts,
                                           align = "h",
                                           widths = rep(1, length(consistency.gender.marg.plts)),  
                                           debug=F)

consistency.age.marg.g = egg::ggarrange(plots= consistency.age.marg.plts,
                                        align = "h",
                                        widths = rep(1, length(consistency.age.marg.plts)),  
                                        debug=F)
# Out:
# Warning message:
# “Using the `size` aesthetic in this geom was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` in the `default_aes` field and elsewhere instead.”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 16 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# plot without title
# plot without title

# %%
marg.g  = ggarrange(consistency.gender.marg.g,
                    consistency.age.marg.g,
                    nrow = 2, 
                    heights = c(0.90,  1.275),
                    widths =  c(1,  1))
                    #font.label = list(size = 25, color = "black", face = "bold", family = NULL)) 

marg.g =  marg.g + annotate("text", x = 0.555, y = -0.01, label = 'bold("Validation")', 
                            parse = TRUE, size = 7.5) +
                   theme(plot.margin = unit(c(0,0,3,0), "lines"))

# %%
options(repr.plot.width = 16, repr.plot.height = 8, repr.plot.res = 200)
marg.g
# Out:
# plot without title

# %%
ggsave(file.path(figure.dir, paste0("Consistency.marg.", metric, ".pdf")), marg.g,
       bg = 'white',
       device = "pdf", width = 16, height = 8, dpi = 600)

# %% [markdown]
# # joint

# %%
############################ Aggranging them with just ggarrange(not egg::ggarrange)  ############################
consistency.gender.joint.plts = F1_heatmap(res.meta.mat = gender.meta.mats[c("bMIND.XY.joint",
                                                                             "Baseline.parametric.full.joint", 
                                                                             "CellDMC.parametric.full.joint", 
                                                                             "TCA.parametric.full.joint", 
                                                                             "TCAx.parametric.X2.joint")],
                                           phenotype = "Sex",
                                           method.names = c("bMIND", "Bulk", "CellDMC", "TCA", "Unico"),
                                           data.names = c("liu", "hannon1", "hannon2", "hannum"),
                                           full.data.names = c("Liu et al. (n= 687)",
                                                               "Hannon et al. I (n= 675)", 
                                                               "Hannon et al. II (n= 665)",
                                                               "Hannum et al. (n= 590)"),
                                           

                                           legend.name = metric, sub.title.name = paste0("Mean ", metric), 
                                           min.quantile = 0.15, max.quantile = 0.9, 
                                           title.size = 15, label.size = label.size, number.size = 5, 
                                           barheight = 5, barwidth = 1, 
                                           barres = 0.15, hide.x = T)

consistency.age.joint.plts = F1_heatmap(res.meta.mat = age.meta.mats[c("bMIND.XY.joint",
                                                                       "Baseline.parametric.full.joint", 
                                                                       "CellDMC.parametric.full.joint", 
                                                                       "TCA.parametric.full.joint", 
                                                                       "TCAx.parametric.X2.joint")],
                                        phenotype = "Age",
                                        method.names = c("bMIND", "Bulk", "CellDMC", "TCA", "Unico"),
                                        data.names = c("liu", "hannon1", "hannon2", "hannum"),
                                        full.data.names = c("Liu et al. (n= 687)",
                                                            "Hannon et al. I (n= 675)", 
                                                            "Hannon et al. II (n= 665)",
                                                            "Hannum et al. (n= 590)"),

                                        legend.name = metric, sub.title.name = paste0("Mean ", metric), 
                                        min.quantile = 0.05, max.quantile = 0.9, 
                                        title.size = 15, label.size = label.size, number.size = 5, 
                                        barheight = 5, barwidth = 1, 
                                        barres = 0.15, hide.x = F)

# %%
consistency.gender.joint.g = egg::ggarrange(plots=consistency.gender.joint.plts,
                                            align = "h",
                                            widths = rep(1, length(consistency.gender.joint.plts)),  
                                            debug=F)

consistency.age.joint.g = egg::ggarrange(plots=consistency.age.joint.plts,
                                         align = "h",
                                         widths = rep(1, length(consistency.age.joint.plts)),  
                                         debug=F)
# Out:
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 16 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# Warning message:
# “Removed 4 rows containing missing values (`geom_text()`).”
# plot without title
# plot without title

# %%
joint.g  = ggarrange(consistency.gender.joint.g,
                     consistency.age.joint.g,
                     nrow = 2, 
                     heights = c(0.90,  1.275),
                     widths =  c(1,  1))

# %%
joint.g = joint.g +  annotate("text", x = 0.555, y = -0.01, label = 'bold("Validation")', 
                              parse = TRUE, size = 7.5) +
                    theme(plot.margin = unit(c(0,0,3,0), "lines"))

# %%
options(repr.plot.width = 16, repr.plot.height = 8, repr.plot.res = 200)
joint.g
# Out:
# plot without title

# %%
ggsave(file.path(figure.dir, paste0("Consistency.joint.", metric, ".pdf")), joint.g,
       bg = 'white',
       device = "pdf", width = 16, height = 8, dpi = 600)

# %% [markdown]
# # Save ggplots and dfs

# %%
fig.list = list(consistency.gender.marg.plts  = consistency.gender.marg.plts, 
                consistency.age.marg.plts     = consistency.age.marg.plts, 
                consistency.gender.joint.plts = consistency.gender.joint.plts, 
                consistency.age.joint.plts    = consistency.age.joint.plts)

saveRDS(fig.list,   file.path(figure.dir, paste0("Consistency.", metric, ".fig.list.rds")))
