# %% [raw]
# # This notebook takes
# # n.copies: number of copies to generate
# # res.dir: path to the directory where the celltype level pseudobulk of Lung HLCA is
# # all the parameters needed to simulate mixtures from the pseudobulk RDS file
# # This notebooks calls the functions in simulate.expression.utils.r (checked in the 0.0.2 notebook)
# # and save n.copies of simulated datasets (generated under different seed)
# # in a subfolder of res.dir. the name of the subfolder contains all parameters used to generate the data

# %%
source("analysis.utils.r")
source("simulate.expression.utils.r")
set.seed(2023)
# Out:
# Warning message:
# “package ‘MASS’ was built under R version 4.1.3”
# Welcome to compositions, a package for compositional data analysis.
# Find an intro with "? compositions"
#
#
#
# Attaching package: ‘compositions’
#
#
# The following objects are masked from ‘package:stats’:
#
#     anova, cor, cov, dist, var
#
#
# The following objects are masked from ‘package:base’:
#
#     %*%, norm, scale, scale.default

# %% [markdown]
# # Parameters

# %%
# partial.W = F # T or F
# source.col = "decon.L1" # "decon.L1" or "decon.L2"
# k = 4
# feature.set = "HEF.10k" # "HVF.10k" or "HEF.10k"

# partial.W = F # T or F
# source.col = "decon.L2" # "decon.L1" or "decon.L2"
# k = 6
# feature.set = "HEF.10k" # "HVF.10k" or "HEF.10k"
# n = 500

# partial.W = F # T or F
# source.col = "decon.L1" # "decon.L1" or "decon.L2"
# k = 4
# feature.set = "HEF.10k" # "HVF.10k" or "HEF.10k"
# n = 250

partial.W = F # T or F
source.col = "decon.L1" # "decon.L1" or "decon.L2"
k = 4
feature.set = "HEF.10k" # "HVF.10k" or "HEF.10k"
n = 100

# %%
n.copies = 20
res.dir = "../Data/RNA/Simulation-Lung/"

# %%
max_sds = 2
m = 600;

fit.dirichlet = F;
add.noise = T; variable_thr = 10^(-4); fill_thr = 10^(-4); expression.qtl = 0; # dont do additional filtering
enrich.low = F; entropy.thr.ratio = 0; enrich.ratio = 0;
scale.max_sds = Inf; scale.factor.thr = 10**(-4)

# %% [markdown]
# ## Directory

# %%
res.folder  = paste("sc-HLCA", if (partial.W) "partial.W" else "all.W", source.col, feature.set, 
                    "k",k,"m",m,"n",n,
                    "dirichlet",substr(as.character(fit.dirichlet), 1,1),
                    "noiseZ",substr(as.character(add.noise), 1,1), "varThr",variable_thr, "filThr",fill_thr, "expQtl",expression.qtl,
                    "enrich",substr(as.character(enrich.low), 1,1), "etpRat",entropy.thr.ratio, "enrichRat",enrich.ratio, 
                    "maxSds",max_sds, "scale.maxSds",scale.max_sds, "scale.factor.thr",scale.factor.thr, sep =  "_")

res.folder  = file.path(res.dir,res.folder)
if (!file.exists(res.folder)){dir.create(file.path(res.folder),recursive = T)}

# %%
res.folder
# Out:
# [1] "../Data/RNA/Simulation-Lung//sc-HLCA_all.W_decon.L1_HEF.10k_k_4_m_600_n_100_dirichlet_F_noiseZ_T_varThr_1e-04_filThr_1e-04_expQtl_0_enrich_F_etpRat_0_enrichRat_0_maxSds_2_scale.maxSds_Inf_scale.factor.thr_1e-04"

# %% [markdown]
# # Load Data

# %%
HLCA.pb = readRDS(file.path(res.dir, 
                            paste0("HLCA.pseudobulk.",
                                    source.col, ".",
                                    if (partial.W) "partial.W." else "all.W.",
                                    "rds")))
                                   
Z.src = HLCA.pb$Z
W.src = HLCA.pb$W

# %%
length(intersect(HLCA.pb$HEF, HLCA.pb$HVF))
# Out:
# [1] 3060

# %%
rowMeans(HLCA.pb$params$mus[head(HLCA.pb$HVF),])
0.000000   0.0000000   0.0000000 0         0
# ENSG00000283003  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283010  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283031  0.000000   1.0379301   0.0000000 0         0
# ENSG00000283033  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283036  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283051  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283052  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283063  2.482745   0.0000000   0.0000000 0         0
# ENSG00000283064  8.317955   0.8213930   2.0901263 0         0
# ENSG00000283071  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283075  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283078  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283103 29.997443  14.8360798  20.5800710 0         0
# ENSG00000283117  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283118  0.000000   0.0000000   0.0000000 0         0
# ENSG00000283125  0.000000   0.6379398   0.0000000 0         0

# %% [markdown]
# # Simulate Data

# %%
if (feature.set == "HVF.10k"){
    Z.src = Z.src[,HLCA.pb$HVF,]
}else{
    Z.src = Z.src[,HLCA.pb$HEF,]
}

# %%
head(dimnames(Z.src)[[2]])
# Out:
# [1] "ENSG00000251562" "ENSG00000168484" "ENSG00000087086" "ENSG00000167996"
# [5] "ENSG00000198804" "ENSG00000198712"

# %%
sim.data.list = list()
for (t in 1:n.copies){
    sim.data = simulate_expression_mixture(Z.src = Z.src, W.src = W.src, 
                                           k = k, m = m, n = n,
                                           fit.dirichlet = fit.dirichlet, 
                                           add.noise = add.noise, variable_thr = variable_thr, fill_thr = fill_thr, expression.qtl = expression.qtl, 
                                           enrich.low = enrich.low, entropy.thr.ratio = entropy.thr.ratio, enrich.ratio = enrich.ratio, 
                                           max_sds = max_sds, scale.max_sds = scale.max_sds, scale.factor.thr = scale.factor.thr, seed.num = t)
    
    # save files for cibersortx to read
    fwrite(as.data.frame(sim.data$X),   
           file = file.path(res.folder,paste0("X.txt.", t)), 
           sep = "\t", quote=FALSE, row.names = T, col.names = T) 

    fwrite(as.data.frame(sim.data$W),   
           file = file.path(res.folder,paste0("W.txt.", t)), 
           sep = "\t", quote=FALSE, row.names = T, col.names = T) 

    # add to list
    sim.data.list[[t]] = sim.data
}
saveRDS(sim.data.list, file.path(res.folder, "sim.data.list.rds"))
# Out:
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"
# [1] "rename feature.ids to replace - or / with . "
# [1] "simulate W"
# [1] "sampling in the more aboundant celltypes (>5%)"
# [1] "n is larger than the number of individuals in W"
# [1] "draw with replacement"
# [1] "extract sources selected in W, only kept those in Z"
# [1] "simulate Z"
# [1] "extracting top quantile :0 features, based on sum of expression in all sources, all samples"
# [1] "sampling 600 random genes no enrichment on low entropy"
# [1] "n is larger than the number of individuals in Z"
# [1] "draw with replacement"
# [1] "generate X"
# [1] "recording parameters used for reproducibility"
# [1] "put everything together"
# [1] "normalization"

# %%
sim.data$variable.feature.source
# Out:
#                 Immune Epithelial Endothelial Stroma
# ENSG00000147576 TRUE   TRUE       TRUE        TRUE
# ENSG00000072110 TRUE   TRUE       TRUE        TRUE
# ENSG00000136770 TRUE   TRUE       TRUE        TRUE
# ENSG00000069329 TRUE   TRUE       TRUE        TRUE
# ENSG00000108604 TRUE   TRUE       TRUE        TRUE
# ENSG00000075391 TRUE   TRUE       TRUE        TRUE
# ENSG00000123739 TRUE   TRUE       TRUE        TRUE
# ENSG00000161021 TRUE   TRUE       TRUE        TRUE
# ENSG00000128524 TRUE   TRUE       TRUE        TRUE
# ENSG00000177606 TRUE   TRUE       TRUE        TRUE
# ENSG00000015285 TRUE   TRUE       TRUE        TRUE
# ENSG00000102977 TRUE   TRUE       TRUE        TRUE
# ENSG00000197170 TRUE   TRUE       TRUE        TRUE
# ENSG00000198053 TRUE   TRUE       TRUE        TRUE
# ENSG00000127774 TRUE   TRUE       TRUE        TRUE
# ENSG00000170881 TRUE   TRUE       TRUE        TRUE
# ENSG00000152558 TRUE   TRUE       TRUE        TRUE
# ENSG00000162545 TRUE   TRUE       TRUE        TRUE
# ENSG00000214087 TRUE   TRUE       TRUE        TRUE
# ENSG00000140678 TRUE   TRUE       TRUE        TRUE
# ENSG00000068831 TRUE   TRUE       TRUE        TRUE
# ENSG00000142507 TRUE   TRUE       TRUE        TRUE
# ENSG00000167962 TRUE   TRUE       TRUE        TRUE
# ENSG00000133661 TRUE   TRUE       TRUE        TRUE
# ENSG00000166949 TRUE   TRUE       TRUE        TRUE
# ENSG00000168439 TRUE   TRUE       TRUE        TRUE
# ENSG00000179820 TRUE   TRUE       TRUE        TRUE
# ENSG00000197182 TRUE   TRUE       TRUE        TRUE
# ENSG00000152684 TRUE   TRUE       TRUE        TRUE
# ENSG00000115561 TRUE   TRUE       TRUE        TRUE
# ⋮               ⋮      ⋮          ⋮           ⋮
# ENSG00000135077 TRUE   TRUE       TRUE        TRUE
# ENSG00000104450 TRUE   TRUE       TRUE        TRUE
# ENSG00000219545 TRUE   TRUE       TRUE        TRUE
# ENSG00000101443 TRUE   TRUE       TRUE        TRUE
# ENSG00000162542 TRUE   TRUE       TRUE        TRUE
# ENSG00000188938 TRUE   TRUE       TRUE        TRUE
# ENSG00000174839 TRUE   TRUE       TRUE        TRUE
# ENSG00000090615 TRUE   TRUE       TRUE        TRUE
# ENSG00000066379 TRUE   TRUE       TRUE        TRUE
# ENSG00000182704 TRUE   TRUE       TRUE        TRUE
# ENSG00000075711 TRUE   TRUE       TRUE        TRUE
# ENSG00000165806 TRUE   TRUE       TRUE        TRUE
# ENSG00000107874 TRUE   TRUE       TRUE        TRUE
# ENSG00000129518 TRUE   TRUE       TRUE        TRUE
# ENSG00000168958 TRUE   TRUE       TRUE        TRUE
# ENSG00000171298 TRUE   TRUE       TRUE        TRUE
# ENSG00000123094 TRUE   TRUE       TRUE        TRUE
# ENSG00000155827 TRUE   TRUE       TRUE        TRUE
# ENSG00000126214 TRUE   TRUE       TRUE        TRUE
# ENSG00000086102 TRUE   TRUE       TRUE        TRUE
# ENSG00000196639 TRUE   TRUE       TRUE        TRUE
# ENSG00000005108 TRUE   TRUE       TRUE        TRUE
# ENSG00000120029 TRUE   TRUE       TRUE        TRUE
# ENSG00000102218 TRUE   TRUE       TRUE        TRUE
# ENSG00000165512 TRUE   TRUE       TRUE        TRUE
# ENSG00000130513 TRUE   TRUE       TRUE        TRUE
# ENSG00000105402 TRUE   TRUE       TRUE        TRUE
# ENSG00000134970 TRUE   TRUE       TRUE        TRUE
# ENSG00000260708 TRUE   TRUE       TRUE        TRUE
# ENSG00000156535 TRUE   TRUE       TRUE        TRUE
