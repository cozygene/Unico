# %%
library("plyr")
library("pracma")
library("ggpubr")
library("ggplot2")
library("gghalves")
library("ggbeeswarm")
set.seed(2023)
# Out:
# Warning message:
# “package ‘plyr’ was built under R version 4.1.2”
# Loading required package: ggplot2
#
#
# Attaching package: ‘ggpubr’
#
#
# The following object is masked from ‘package:plyr’:
#
#     mutate

# %%
data.dir    = file.path("../Data/RNA/CREBBP/")
res.dir     = file.path("../Result/RNA/CREBBP/")
figure.dir  = file.path("../Figure/CREBBP/")

if (!file.exists(figure.dir)){
    dir.create(figure.dir, recursive = T)
}

# %%
CREBBP.dat  = readRDS(file.path(data.dir, "CREBBP.dat.rds"))
CREBBP.eval = readRDS(file.path(res.dir, "CREBBP.eval.rds"))

# %% [markdown]
# # DE genes and mutation status

# %%
inc.genes  = CREBBP.dat$inc.genes
dec.genes  = CREBBP.dat$dec.genes
samples.mt = CREBBP.dat$samples.mt
samples.wt = CREBBP.dat$samples.wt

print(paste0("length inc.genes: ", length(inc.genes)))
print(paste0("length dec.genes: ", length(dec.genes)))
print(paste0("length samples.mt: ", length(samples.mt)))
print(paste0("length samples.wt: ", length(samples.wt)))
# Out:
# [1] "length inc.genes: 275"
# [1] "length dec.genes: 219"
# [1] "length samples.mt: 14"
# [1] "length samples.wt: 10"

# %% [markdown]
# # Gene experiemnt (W, X, C1)

# %%
key     = "genes"

W = CREBBP.dat$expm.dat[[key]]$W
X = CREBBP.dat$expm.dat[[key]]$X
source.ids  = colnames(W)
feature.ids = rownames(X)
sample.ids  = rownames(W)

k = length(source.ids)
m = length(feature.ids)
n = length(sample.ids)

print(source.ids)
# Out:
# [1] "Bcells"    "Remaining" "TcellsCD4" "TcellsCD8"

# %% [markdown]
# # Load model eval

# %%
########################################### Color code ################################################
library(RColorBrewer)
display.brewer.all(colorblindFriendly = TRUE)

method.colors = list("Baseline"   = brewer.pal(n = 8, name = "Set2")[8],
                     "Bulk"       = brewer.pal(n = 8, name = "Dark2")[7],
                     "CIBERSORTx" = brewer.pal(n = 8, name = "Set2")[5],
                     "TCA"        = brewer.pal(n = 8, name = "Set2")[6],
                     "bMIND"      = brewer.pal(n = 8, name = "Set2")[3],
                     "TCAx"       = brewer.pal(n = 8, name = "Set2")[4],
                     "Unico"      = brewer.pal(n = 8, name = "Set2")[4])



mt.color = brewer.pal(n = 11, name = "RdYlBu")[1]
wt.color = brewer.pal(n = 11, name = "RdBu")[6]
# Out:
# plot without title

# %% [markdown]
# # Supp text full boxplot

# %%
scientific_pvals_10x <- function(values, digits = 1) {
    if(!is.numeric(values)){
        stop("values must be numbers")
    }
    if(grepl("^\\d{2}$", digits)){
        stop("digits must a one or two digit whole number")
    }

    x <- sprintf(paste0("%.", digits, "e"), values)
    x <- gsub("^(.*)e", "'\\1'e", x)
    longestExponent <- max(sapply(gregexpr("\\d{1,}$", x), attr, 'match.length'))
    zeroTrimmed <- ifelse(longestExponent > 2,
                          paste0("\\1", paste(rep("~", times = longestExponent-1), collapse = "")),
                          "\\1")
    x <- gsub("(e[+|-])[0]", zeroTrimmed, x)

    x <- gsub("e", "~x~10^", x)

    if(any(grepl("\\^\\-", x))){
        x <- gsub("\\^\\+", "\\^~~", x)
    } else {
        x <- gsub("\\^\\+", "\\^", x)
    }
    # return this as an expression
    #parse(text="P = " ~ x)
    return(x)
}

# %%
methods = c("Baseline", "CIBERSORTx", "TCA", "Bulk", "bMIND", "TCAx")
logDiff.df = CREBBP.eval$tensor$logDiff.df

# %%
colnames(logDiff.df)[which(colnames(logDiff.df) == "bMIND.scale")] = "bMIND"

# %%
logDiff.df
# Out:
#           Bulk         Baseline    CIBERSORTx    TCA           TCAx
# ZYG11B     0.259998527 0.42545134   0.114951882   1.509812e-01  0.280688689
# PIAS1      0.154892908 0.31600046   0.048369229   8.315048e-02  0.201243198
# SMCHD1     0.199521192 0.35901529   0.122499180   1.366608e-01  0.164292859
# CCNI       0.019681314 0.19702826   0.012256381   1.356358e-02 -0.003250459
# ORMDL3    -0.181131173 0.02755066   0.000000000  -1.397701e-02 -0.187772565
# TSPYL1     0.105909234 0.27805016   0.089784335   7.956507e-02  0.149018477
# ORAI2     -0.210209110 0.03513845  -0.127742841  -1.043317e-01 -0.238831049
# CXorf38   -0.090994380 0.14884076   0.004904049   6.948768e-04 -0.080086864
# TTN        0.181786617 0.38153683   0.002616326   9.035688e-02  0.126817011
# CSDE1      0.008013025 0.18704828  -0.015648094  -2.503676e-02 -0.003524940
# KIAA2018   0.231842421 0.39717055   0.156067865   5.474684e-03  0.256640234
# TMEM66    -0.038530957 0.11571945  -0.009132841  -7.528510e-03  0.029639863
# IKZF1      0.027490685 0.24613798   0.028653976   9.319476e-03  0.011553879
# MAP3K1     0.258344183 0.44089241   0.136622423   2.253021e-01  0.240392238
# REPS1      0.270387398 0.43276810   0.121689490   2.332899e-01  0.362712724
# PNRC1     -0.112607329 0.09825721  -0.087793228  -5.954225e-02 -0.128943007
# PHF3       0.182060959 0.34831982   0.213237223   8.733144e-02  0.170038227
# CAMK2D     0.464260518 0.64850335   0.164692789   3.134421e-01  0.289803786
# KLRC4      1.433322752 1.63878290   0.000000000   1.133012e+00  1.311231989
# DIP2B      0.250282474 0.40392291   0.132693102   1.651533e-01  0.277519260
# PKIA      -0.060273377 0.12007838  -0.074680977  -3.150788e-02 -0.094138124
# KIAA1324L -0.202309589 0.05825533   0.000000000  -7.440916e-03 -0.265962906
# SNORD8    -0.009490160 0.18204635  -0.006962361   4.164122e-02  0.026160929
# PPM1A      0.131594822 0.27128795   0.051109976   4.040659e-02  0.198441489
# TRIO       0.555716060 0.75548120   0.261663295   2.742037e-01  0.423040461
# UBL3      -0.006835242 0.13207079   0.019529548  -1.905748e-02  0.012278692
# ZFX        0.401875518 0.55983125   0.276151110   8.829479e-02  0.437168027
# FBXL17    -0.039924140 0.13854098  -0.029403462  -1.127824e-09 -0.054138744
# PPP3CA    -0.058414337 0.10557042  -0.005621256  -1.170333e-01 -0.097138027
# RSBN1      0.063406924 0.21367548   0.012804241   3.061026e-02  0.103049345
# ⋮         ⋮            ⋮           ⋮             ⋮             ⋮
# IKZF1      0.022908768  0.026783597
# MAP3K1     0.224545055  0.298868286
# REPS1      0.310739356  0.307634890
# PNRC1     -0.128285363 -0.068889907
# PHF3       0.139651550  0.164448706
# CAMK2D     0.333378682  0.418693655
# KLRC4      1.680139357  2.356438370
# DIP2B      0.240378848  0.237333470
# PKIA      -0.090528890 -0.080733386
# KIAA1324L -0.181114897 -0.238431358
# SNORD8     0.072607399  0.033493259
# PPM1A      0.080962944  0.089239915
# TRIO       0.428917274  0.620780177
# UBL3      -0.034592513 -0.031188129
# ZFX        0.384190727  0.486568717
# FBXL17    -0.028240808 -0.035453265
# PPP3CA    -0.113328610 -0.147501326
# RSBN1      0.045033546  0.044241453
# ⋮         ⋮            ⋮
# IRF5      -0.04165962  -0.07685101
# CD58      -0.18829385  -0.10238775
# POP5       0.07084334   0.07129895
# CTSH      -0.13457329  -0.13238044
# IMP4      -0.19742423  -0.18181034
# ERLIN1    -0.03244968  -0.03246781
# RIOK1     -0.39188795  -0.39712885
# SNX5      -0.05509157  -0.05422094
# HLA-DRB1  -0.21855099  -0.21953896
# PASK      -0.10461146  -0.05466969
# ABCF1     -0.15759010  -0.14798010
# RAB3GAP2  -0.03062805  -0.00638137
# CPNE5     -0.64869996  -0.98475415
# ASNS      -0.57779369  -0.57530357
# EIF1AY    -1.54870326  -1.62256418
# ADSS      -0.06381602  -0.06875552
# NAMPT     -0.39654377  -0.25571290
# ATP1A1     0.14062088   0.12997297
# TTTY15    -0.64820606  -0.53212090
# RGS10     -0.51068762  -0.41841941
# BPNT1     -0.22547957  -0.17367925
# RFWD2     -0.13573038  -0.14028129
# HLA-DRA   -0.37776065  -0.37385346
# CENPK      0.20510896   0.19831258
# WEE1      -0.59348949  -0.68637508
# IARS      -0.13718826  -0.15083590
# MDFIC     -0.88769386  -0.78505655
# HLA-DMB   -0.32788459  -0.33398556
# PSMC2     -0.27061323  -0.24215923
# HLA-DRB6  -0.60312737  -0.59951370

# %%
de.plot.df = data.frame()
for (method in methods){
    method.df = data.frame(diff     = logDiff.df[c(inc.genes, dec.genes), method],
                           method   = rep(method, m),
                           DE.type  = c(rep("Up Regulated", length(inc.genes)), 
                                        rep("Down Regulated", length(dec.genes))))
    de.plot.df = rbind(de.plot.df, method.df)
}
de.plot.df$method = factor(de.plot.df$method, levels = methods)
levels(de.plot.df$method)[match("TCAx",levels(de.plot.df$method))] <- "Unico"

# %%
de.plot.df
# Out:
#           diff         method   DE.type
# ZYG11B    0.42545134   Baseline Up Regulated
# PIAS1     0.31600046   Baseline Up Regulated
# SMCHD1    0.35901529   Baseline Up Regulated
# CCNI      0.19702826   Baseline Up Regulated
# ORMDL3    0.02755066   Baseline Up Regulated
# TSPYL1    0.27805016   Baseline Up Regulated
# ORAI2     0.03513845   Baseline Up Regulated
# CXorf38   0.14884076   Baseline Up Regulated
# TTN       0.38153683   Baseline Up Regulated
# CSDE1     0.18704828   Baseline Up Regulated
# KIAA2018  0.39717055   Baseline Up Regulated
# TMEM66    0.11571945   Baseline Up Regulated
# IKZF1     0.24613798   Baseline Up Regulated
# MAP3K1    0.44089241   Baseline Up Regulated
# REPS1     0.43276810   Baseline Up Regulated
# PNRC1     0.09825721   Baseline Up Regulated
# PHF3      0.34831982   Baseline Up Regulated
# CAMK2D    0.64850335   Baseline Up Regulated
# KLRC4     1.63878290   Baseline Up Regulated
# DIP2B     0.40392291   Baseline Up Regulated
# PKIA      0.12007838   Baseline Up Regulated
# KIAA1324L 0.05825533   Baseline Up Regulated
# SNORD8    0.18204635   Baseline Up Regulated
# PPM1A     0.27128795   Baseline Up Regulated
# TRIO      0.75548120   Baseline Up Regulated
# UBL3      0.13207079   Baseline Up Regulated
# ZFX       0.55983125   Baseline Up Regulated
# FBXL17    0.13854098   Baseline Up Regulated
# PPP3CA    0.10557042   Baseline Up Regulated
# RSBN1     0.21367548   Baseline Up Regulated
# ⋮         ⋮            ⋮        ⋮
# IRF55     -0.089249187 Unico    Down Regulated
# CD585     -0.124765071 Unico    Down Regulated
# POP55      0.064570060 Unico    Down Regulated
# CTSH5     -0.154860339 Unico    Down Regulated
# IMP45     -0.176316787 Unico    Down Regulated
# ERLIN15   -0.033553382 Unico    Down Regulated
# RIOK15    -0.335444584 Unico    Down Regulated
# SNX55     -0.059776387 Unico    Down Regulated
# HLA-DRB15 -0.193430032 Unico    Down Regulated
# PASK5     -0.025672038 Unico    Down Regulated
# ABCF15    -0.187052849 Unico    Down Regulated
# RAB3GAP25  0.008483524 Unico    Down Regulated
# CPNE55    -0.686900742 Unico    Down Regulated
# ASNS5     -0.702642496 Unico    Down Regulated
# EIF1AY5   -0.973427332 Unico    Down Regulated
# ADSS5     -0.015826511 Unico    Down Regulated
# NAMPT5    -0.291575523 Unico    Down Regulated
# ATP1A15    0.131885642 Unico    Down Regulated
# TTTY155   -0.513324742 Unico    Down Regulated
# RGS105    -0.391743815 Unico    Down Regulated
# BPNT15    -0.166467746 Unico    Down Regulated
# RFWD25    -0.165077877 Unico    Down Regulated
# HLA-DRA5  -0.345081082 Unico    Down Regulated
# CENPK5     0.244032463 Unico    Down Regulated
# WEE15     -0.699126109 Unico    Down Regulated
# IARS6     -0.170887318 Unico    Down Regulated
# MDFIC5    -0.681786352 Unico    Down Regulated
# HLA-DMB5  -0.347727924 Unico    Down Regulated
# PSMC25    -0.237970395 Unico    Down Regulated
# HLA-DRB65 -0.637845128 Unico    Down Regulated

# %%
pvals.inc = CREBBP.eval$tensor$pvals.inc
pvals.dec = CREBBP.eval$tensor$pvals.dec

colnames(pvals.inc)[which(colnames(pvals.inc) == "bMIND.scale")] = "bMIND"
colnames(pvals.dec)[which(colnames(pvals.dec) == "bMIND.scale")] = "bMIND"

# %%
pvals.inc
# Out:
#             Bulk         Baseline CIBERSORTx   TCA          TCAx
# Bulk        1.000000e+00 1        4.913007e-17 2.798769e-13 2.644328e-03
# Baseline    3.764587e-47 1        5.951814e-46 6.717527e-47 9.316539e-47
# CIBERSORTx  1.000000e+00 1        1.000000e+00 6.278345e-01 1.000000e+00
# TCA         1.000000e+00 1        3.724521e-01 1.000000e+00 1.000000e+00
# TCAx        9.973619e-01 1        1.003960e-10 3.546434e-08 1.000000e+00
# bMIND.scale 9.999699e-01 1        2.624104e-10 1.880980e-08 8.876199e-01
# bMIND.log   9.214242e-01 1        2.322626e-12 2.155062e-12 9.648510e-02
#             bMIND        bMIND.log
# Bulk        3.015634e-05 7.868692e-02
# Baseline    1.883306e-45 1.944940e-45
# CIBERSORTx  1.000000e+00 1.000000e+00
# TCA         1.000000e+00 1.000000e+00
# TCAx        1.125248e-01 9.036443e-01
# bMIND.scale 1.000000e+00 9.999390e-01
# bMIND.log   6.123304e-05 1.000000e+00

# %%
title.size = 20
lab.size = 18


tp = ggplot(de.plot.df, aes(x=DE.type, y=diff, fill = method)) + 
     geom_beeswarm(aes(DE.type, y = diff, fill = method, colour = method),
                   priority = 'density',
                   side = -1, dodge.width = 0.8, cex = 0.15, size = 1.75, colour = "black", #dot border 
                   pch = 21, shape = 22, stroke = 0, show.legend = F) +

     geom_half_boxplot(aes(fill = method), side = 'r', color = 'black', 
                       outlier.size = NA, outlier.color = NA, notchwidth = 0.5, size = 0.7, #thickness of the line 
                       width = 0.6, position = position_dodge(0.8), alpha = 1) +  
     geom_hline(yintercept=0, linetype='dotted', col = 'grey', size=1) + 
    
    
     scale_fill_manual(values = as.character(method.colors[levels(de.plot.df$method)]), name=NULL) +  
     coord_cartesian(ylim = c(-65,2)) + # for annotation to have space
     scale_y_continuous(breaks = c(-2, -1, 0, 1, 2),
                        trans = scales::pseudo_log_trans(sigma = 0.25)) + 
     scale_x_discrete(labels=c("Down Regulated" = "CREBBP down-regulated genes \n (lower is better)", 
                               "Up Regulated"   = "CREBBP up-regulated genes \n (higher is better)")) +
 
     #ylab(expression(atop("Differences in "*Log[2]*" Expression", "(Deconvolution B cells)"))) + 
     ylab("Log fold change") + 

     #ggtitle("CREBBP Mutation")  + 
     ggtitle("")  + 

     theme_classic() + # later operation will overide this
     theme(plot.title = element_text(hjust = 0.5, size = title.size, face="bold")) + 
     # label size
     theme(axis.title.x = element_blank()) + 
     theme(axis.title.y = element_text(size = lab.size + 2, face="bold")) + 
     #ticks size
     theme(axis.text.y = element_text(size = lab.size, face="bold")) +
     theme(axis.text.x = element_text(size = lab.size, face="bold"))+
     theme(legend.text = element_text(size = lab.size, face="bold"))
# Out:
# Warning message:
# “Duplicated aesthetics after name standardisation: shape”
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”

# %%
options(repr.plot.width = 16, repr.plot.height = 6, repr.plot.res = 150)
tp
# Out:
# plot without title

# %%
h.loc  = linspace(0.665, 1.33, 6)
v.loc  = -exp(linspace(0.9, 3.75, 5))
v.size = -(exp(linspace(0.4, 1.5, 5))-1)
p.size = 4.75

df1 <- data.frame(a = c(h.loc[1],           h.loc[1], h.loc[6], h.loc[6]), 
                  b = c(v.loc[1]-v.size[1], v.loc[1], v.loc[1], v.loc[1]-v.size[1]))

df2 <- data.frame(a = c(h.loc[2],           h.loc[2], h.loc[6], h.loc[6]), 
                  b = c(v.loc[2]-v.size[2], v.loc[2], v.loc[2], v.loc[2]-v.size[2]))

df3 <- data.frame(a = c(h.loc[3],           h.loc[3], h.loc[6], h.loc[6]), 
                  b = c(v.loc[3]-v.size[3], v.loc[3], v.loc[3], v.loc[3]-v.size[3]))

df4 <- data.frame(a = c(h.loc[4],           h.loc[4], h.loc[6], h.loc[6]), 
                  b = c(v.loc[4]-1.5 * v.size[4], v.loc[4], v.loc[4], v.loc[4]-1.5 * v.size[4]))

df5 <- data.frame(a = c(h.loc[5],           h.loc[5], h.loc[6], h.loc[6]), 
                  b = c(v.loc[5]-2 * v.size[5], v.loc[5], v.loc[5], v.loc[5]-2 * v.size[5]))


df6  <- data.frame(a = df1$a + 1, b = df1$b)
df7  <- data.frame(a = df2$a + 1, b = df2$b)
df8  <- data.frame(a = df3$a + 1, b = df3$b)
df9  <- data.frame(a = df4$a + 1, b = df4$b)
df10 <- data.frame(a = df5$a + 1, b = df5$b)


tp = tp + geom_line(data = df1, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df2, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df3, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df4, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df5, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df6, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df7, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df8, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df9, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df10,aes(x = a, y = b), inherit.aes = FALSE) +

          annotate("text", x = (h.loc[1]+ h.loc[6])/2,       y = v.loc[1] + 1.5*v.size[1],      label = paste0("\'P = \'~", scientific_pvals_10x(pvals.dec["TCAx", "Baseline"],   digits = 1)), parse=TRUE, size = p.size) + 
          annotate("text", x = (h.loc[2]+ h.loc[6])/2,       y = v.loc[2] + 1.5*v.size[2],      label = paste0("\'P = \'~", scientific_pvals_10x(pvals.dec["TCAx", "CIBERSORTx"], digits = 1)), parse=TRUE, size = p.size) + 
          annotate("text", x = (h.loc[3]+ h.loc[6])/2,       y = v.loc[3] + 2.0*v.size[3],      label = paste0("\'P = \'~", scientific_pvals_10x(pvals.dec["TCAx", "TCA"],        digits = 1)), parse=TRUE, size = p.size) +
          annotate("text", x = (h.loc[4]+ h.loc[6])/2,       y = v.loc[4] + 2.5*v.size[4],      label = paste0("\'P = \'~", scientific_pvals_10x(pvals.dec["TCAx", "Bulk"],       digits = 1)), parse=TRUE, size = p.size) +
          annotate("text", x = (h.loc[5]+ h.loc[6])/2,       y = v.loc[5] + 2.5*v.size[5],      label = paste0("\'P = \'~", scientific_pvals_10x(pvals.dec["TCAx", "bMIND"],      digits = 1)), parse=TRUE, size = p.size) +

          annotate("text", x = 1 + (h.loc[1]+ h.loc[6])/2,   y = (v.loc[1] + 1.5*v.size[1]),    label = paste0("\'P = \'~", scientific_pvals_10x(pvals.inc["TCAx", "Baseline"],   digits = 1)), parse=TRUE, size = p.size) + 
          annotate("text", x = 1 + (h.loc[2]+ h.loc[6])/2,   y = (v.loc[2] + 1.5*v.size[2]),    label = paste0("\'P = \'~", scientific_pvals_10x(pvals.inc["TCAx", "CIBERSORTx"], digits = 1)), parse=TRUE, size = p.size) + 
          annotate("text", x = 1 + (h.loc[3]+ h.loc[6])/2,   y = (v.loc[3] + 2.0*v.size[3]),    label = paste0("\'P = \'~", scientific_pvals_10x(pvals.inc["TCAx", "TCA"],        digits = 1)), parse=TRUE, size = p.size) +
          annotate("text", x = 1 + (h.loc[4]+ h.loc[6])/2,   y = (v.loc[4] + 2.5*v.size[4]),    label = paste0("\'P = \'~", scientific_pvals_10x(pvals.inc["TCAx", "Bulk"],       digits = 1)), parse=TRUE, size = p.size) +
          annotate("text", x = 1 + (h.loc[5]+ h.loc[6])/2,   y = (v.loc[5] + 2.5*v.size[5]),    label = paste0("\'P = \'~", scientific_pvals_10x(pvals.inc["TCAx", "bMIND"],      digits = 1)), parse=TRUE, size = p.size) #+

# %%
options(repr.plot.width = 16, repr.plot.height = 6, repr.plot.res = 150)
tp
# Out:
# plot without title

# %%
############################ figure boxplot ############################
W.df  = data.frame(W        = c(W[samples.mt, "Bcells"], W[samples.wt, "Bcells"]),
                   mutation = c(rep("MT", length(samples.mt)), rep("WT", length(samples.wt))))
W.df$mutation = factor(W.df$mutation, levels = c("WT","MT"))


wp = ggplot(W.df, aes(x=mutation, y=W, fill = mutation)) + #geom_boxplot()
     geom_dotplot(binaxis = "y", stackdir = "down", dotsize = 2.5) + 
     geom_half_boxplot(aes(fill = mutation), side = 'r', color = 'black', 
                       outlier.size = NA, outlier.color = NA, notchwidth = 0.5, size = 1, #thickness of the line 
                       width = 0.8, position = position_dodge(0.9), alpha = 1) + 
     #scale_y_continuous(position = "right") + 
     scale_fill_manual(values = c(wt.color, mt.color), name=NULL) + 
     coord_cartesian(ylim = c(0,0.8))  + 
     ylab(expression(atop("CIBERSORTx Estimated","B cells Proportion"))) + 


     theme_classic() + # later operation will overide this
     theme(legend.position = "none") + 
     theme(plot.title = element_text(hjust = 0.5, size = title.size, face="bold")) + 
     theme(axis.title.x = element_blank()) + 
     theme(axis.title.y = element_text(size = title.size)) + 
     #ticks size
     theme(axis.text.y = element_text(size = lab.size, face="bold")) +
     theme(axis.text.x = element_text(size = lab.size + 5, face="bold"))

# %%
options(repr.plot.width = 3, repr.plot.height = 6, repr.plot.res = 150)
wp
# Out:
# Bin width defaults to 1/30 of the range of the data. Pick better value with
# `binwidth`.
# plot without title

# %% [markdown]
# # Regression

# %%
str(CREBBP.eval$regression)
# Out:
# List of 4
#  $ method.log10p.list:List of 7
#   ..$ Bulk       : num [1:494, 1:3] 18 16.1 14 27.1 16 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ Baseline   : num [1:494, 1:3] 14.7 13 10.3 25.3 12.5 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ CIBERSORTx : num [1:494, 1:3] 22.1 26.7 22.1 37.5 0 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ TCA        : num [1:494, 1:3] 23.3 24.3 16.4 28.6 28.4 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ TCAx       : num [1:494, 1:3] 17 10.4 15.6 26.1 14 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ bMIND.scale: num [1:494, 1:3] 19.4 19.9 17.8 26.2 13.6 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ bMIND.log  : num [1:494, 1:3] 18.9 18.9 14.6 25.9 14.5 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#  $ method.beta.list  :List of 7
#   ..$ Bulk       : num [1:494, 1:3] 25 22.6 16.6 67 23.2 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ Baseline   : num [1:494, 1:3] 9.26 10.3 7 19.98 11.92 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ CIBERSORTx : num [1:494, 1:3] 43.1 73.4 41.3 206.1 0 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ TCA        : num [1:494, 1:3] 47.5 59.2 24.7 88.6 96.3 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ TCAx       : num [1:494, 1:3] 23.3 11.8 22.1 69.2 18.9 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ bMIND.scale: num [1:494, 1:3] 31 35.8 29 64.5 18.4 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#   ..$ bMIND.log  : num [1:494, 1:3] 29.2 32.2 19.7 66.8 20.3 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:494] "ZYG11B" "PIAS1" "SMCHD1" "CCNI" ...
#   .. .. ..$ : chr [1:3] "(Intercept)" "W.test.source" "mutation.status"
#  $ reg.pvals.inc     : num [1:7, 1:7] 1 1 0.993 0.124 0.147 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:7] "Bulk" "Baseline" "CIBERSORTx" "TCA" ...
#   .. ..$ : chr [1:7] "Bulk" "Baseline" "CIBERSORTx" "TCA" ...
#  $ reg.pvals.dec     : num [1:7, 1:7] 1.00 1.00 8.41e-01 5.15e-01 5.13e-10 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:7] "Bulk" "Baseline" "CIBERSORTx" "TCA" ...
#   .. ..$ : chr [1:7] "Bulk" "Baseline" "CIBERSORTx" "TCA" ...

# %%
method.beta.list = CREBBP.eval$regression$ method.beta.list 
reg.pvals.inc    = CREBBP.eval$regression$ reg.pvals.inc
reg.pvals.dec    = CREBBP.eval$regression$ reg.pvals.dec

names(method.beta.list)[which(names(method.beta.list) == "bMIND.scale")] = "bMIND"
colnames(reg.pvals.inc)[which(colnames(reg.pvals.inc) == "bMIND.scale")] = "bMIND"
rownames(reg.pvals.inc)[which(rownames(reg.pvals.inc) == "bMIND.scale")] = "bMIND"
colnames(reg.pvals.dec)[which(colnames(reg.pvals.dec) == "bMIND.scale")] = "bMIND"
rownames(reg.pvals.dec)[which(rownames(reg.pvals.dec) == "bMIND.scale")] = "bMIND"

# %%
method.beta.list
# Out:
# $Bulk
#           (Intercept) W.test.source mutation.status
# ZYG11B      25.023596   3.325041863    0.7103814645
# PIAS1       22.585733   2.837818947    0.3919449383
# SMCHD1      16.553286   4.193805672    0.3389837122
# CCNI        67.032429   5.724280115   -0.2194985572
# ORMDL3      23.196256  -1.609621066   -0.4435271601
# TSPYL1      31.043893   2.254576909    0.3859083529
# ORAI2       17.170511  -0.605451601   -0.3613767643
# CXorf38     17.649806  -0.017546016   -0.0370187995
# TTN          9.151093   0.954595052    0.3368699492
# CSDE1       38.179584   2.195974036   -0.0005923267
# KIAA2018    16.385926   4.194526273    0.7060084588
# TMEM66      47.544929  -2.406696432   -0.0866433646
# IKZF1       33.420825   0.360929571    0.1094877247
# MAP3K1      18.355884   2.895150060    0.3338299743
# REPS1       21.450587   3.287202682    0.5841308727
# PNRC1       25.807306   1.879707363   -0.4538455909
# PHF3        12.595797   2.537691672    0.3689609775
# CAMK2D      20.299492   2.949689439    0.9292349719
# KLRC4        2.045012   2.732391273    0.6148647891
# DIP2B       23.870578   0.067634114    0.9099068677
# PKIA        16.037002   0.901689929   -0.2768879093
# KIAA1324L    6.841935   1.203077288    0.0126475845
# SNORD8      13.277090   1.701925030   -0.1471678850
# PPM1A       24.587214   2.443383411    0.4117038085
# TRIO        11.753917   1.515669372    0.9999255067
# UBL3        19.120786  -0.046112595   -0.0451979625
# ZFX         15.146084   3.628653762    0.8478485494
# FBXL17      31.417294  -0.559093732   -0.2116214623
# PPP3CA      17.411890   4.362723463   -0.4049706060
# RSBN1       21.281864   0.767142734    0.1462960646
# YTHDC1      24.023712   0.791893134    0.3233418072
# SPOP        68.396814  -0.539307133    0.3104390433
# TCL6         7.676133  -1.283930323    0.1491302193
# QRSL1       11.132747   3.425906889    0.9315510367
# NFATC3      29.673187   2.814142315    0.6258056171
# PSMG4       20.359199   0.577613977    -0.691163795
# CYP51A1     11.478538  -2.028034556    -0.874270060
# VPS52       20.341516  -3.155681410     0.097481826
# RFX5        31.755295  -0.376837647    -0.371547212
# PTAFR       10.548164  -1.628432696    -1.202138185
# HLA-DMA     24.645467  -1.061017231    -1.080233664
# MRPL39      23.118790   0.036793547    -0.507168996
# SMG7        17.616040   0.004190409     0.262944615
# CDC16       34.872391  -1.420398879     0.538108944
# UBA3        27.736121  -4.144874805     0.429604753
# ITPA        39.284929   1.613818784     0.017817923
# SRPK1       32.534575   1.355363512    -0.065037295
# C17orf89    35.689706  -1.341330734    -0.164106555
# SS18L2      51.553131   0.881686697    -0.834467814
# RAB33A       8.399160   0.887684521    -1.045304689
# TRAPPC5     22.847663   0.939034166    -0.363182112
# OSBPL3      14.410731  -3.645979756     0.128035413
# TSPYL5       4.658129   2.363359931    -0.734866694
# PHTF2       17.948553  -0.585296896    -0.186652580
# RHOQ        15.668001  -0.229227237     0.154638017
# FANCD2      24.948684  -2.258986351     0.245906442
# GSTP1       17.543321   0.058712124    -0.874134929
# IRF5        21.975391   0.229343450    -0.213570238
# CD58        15.769842  -1.725689682    -0.024792867
# POP5        30.919714  -2.449153467     0.253749015
# CTSH        37.637138   0.911849303    -0.506588400
# IMP4        22.607450  -2.241670232    -0.386538437
# ERLIN1      38.791889   3.434890685    -0.413822835
# RIOK1       23.092378  -0.362248382    -0.934363472
# SNX5        42.186592  -0.462240569    -0.196044185
# HLA-DRB1    19.571774   0.975561598    -0.305718538
# PASK        22.325031  -3.161420612     0.076447119
# ABCF1       25.778682  -0.907993410    -0.398654905
# RAB3GAP2    28.694602  -0.852971658     0.103767423
# CPNE5       10.068462   0.348453384    -0.988343281
# ASNS        19.350614  -2.701213126    -0.683135688
# EIF1AY       2.733349  -0.251171069    -0.894482718
# ADSS        31.201093   0.132627297    -0.241289444
# NAMPT       18.994626  -0.012481439    -0.593908523
# ATP1A1      22.883679   0.504085030     0.246865819
# TTTY15       6.087322  -0.136800148    -0.698558503
# RGS10       21.302684   1.748081476    -0.851930938
# BPNT1       16.570641  -1.806733678    -0.386979792
# RFWD2       38.333871   2.062814071    -0.699175268
# HLA-DRA     35.781736   1.592207484    -1.106766863
# CENPK       11.424687  -3.100209862     0.309882676
# WEE1        16.382220  -1.812394754    -1.125511614
# IARS        38.090910  -1.114040626    -0.445411681
# MDFIC       12.978381   0.398050660    -1.299566047
# HLA-DMB     34.038404  -1.230809059    -0.815713420
# PSMC2       27.924566   0.027691029    -0.878643294
# HLA-DRB6    16.067907  -2.707943045    -0.844442337

# %%
reg.plot.df = data.frame()
for (method in methods){
    method.df = data.frame(beta     = method.beta.list[[method]][c(inc.genes, dec.genes), "mutation.status"],
                           method   = rep(method, m),
                           DE.type  = c(rep("Up Regulated", length(inc.genes)), 
                                        rep("Down Regulated", length(dec.genes))))
    reg.plot.df = rbind(reg.plot.df, method.df)
}
reg.plot.df$method = factor(reg.plot.df$method, levels = c('Baseline','CIBERSORTx','TCA', 'Bulk', 'bMIND', 'TCAx'))
levels(reg.plot.df$method)[match("TCAx",levels(reg.plot.df$method))] <- "Unico"

# %%
reg.plot.df
# Out:
#           beta        method   DE.type
# ZYG11B     0.37547720 Baseline Up Regulated
# PIAS1      0.23414369 Baseline Up Regulated
# SMCHD1     0.20326546 Baseline Up Regulated
# CCNI      -0.10657826 Baseline Up Regulated
# ORMDL3    -0.37332068 Baseline Up Regulated
# TSPYL1     0.15409091 Baseline Up Regulated
# ORAI2     -0.33399929 Baseline Up Regulated
# CXorf38   -0.04874029 Baseline Up Regulated
# TTN        0.25422821 Baseline Up Regulated
# CSDE1     -0.02246122 Baseline Up Regulated
# KIAA2018   0.33569551 Baseline Up Regulated
# TMEM66    -0.09178619 Baseline Up Regulated
# IKZF1      0.04537818 Baseline Up Regulated
# MAP3K1     0.20954670 Baseline Up Regulated
# REPS1      0.35054867 Baseline Up Regulated
# PNRC1     -0.36052626 Baseline Up Regulated
# PHF3       0.27033463 Baseline Up Regulated
# CAMK2D     0.58176166 Baseline Up Regulated
# KLRC4      0.53384744 Baseline Up Regulated
# DIP2B      0.56012543 Baseline Up Regulated
# PKIA      -0.22693690 Baseline Up Regulated
# KIAA1324L  0.00218683 Baseline Up Regulated
# SNORD8    -0.11341533 Baseline Up Regulated
# PPM1A      0.19965261 Baseline Up Regulated
# TRIO       0.71101371 Baseline Up Regulated
# UBL3      -0.05640270 Baseline Up Regulated
# ZFX        0.49278383 Baseline Up Regulated
# FBXL17    -0.12865085 Baseline Up Regulated
# PPP3CA    -0.29873586 Baseline Up Regulated
# RSBN1      0.08754516 Baseline Up Regulated
# ⋮         ⋮           ⋮        ⋮
# IRF55     -0.19763673 Unico    Down Regulated
# CD585      0.03422946 Unico    Down Regulated
# POP55      0.28993553 Unico    Down Regulated
# CTSH5     -0.53785425 Unico    Down Regulated
# IMP45     -0.42871024 Unico    Down Regulated
# ERLIN15   -0.37673263 Unico    Down Regulated
# RIOK15    -0.82197071 Unico    Down Regulated
# SNX55     -0.20622121 Unico    Down Regulated
# HLA-DRB15 -0.35199342 Unico    Down Regulated
# PASK5      0.15842114 Unico    Down Regulated
# ABCF15    -0.42271091 Unico    Down Regulated
# RAB3GAP25  0.18404013 Unico    Down Regulated
# CPNE55    -0.99416058 Unico    Down Regulated
# ASNS5     -0.68606933 Unico    Down Regulated
# EIF1AY5   -0.95253864 Unico    Down Regulated
# ADSS5     -0.02829420 Unico    Down Regulated
# NAMPT5    -0.54677898 Unico    Down Regulated
# ATP1A15    0.24522246 Unico    Down Regulated
# TTTY155   -0.78584091 Unico    Down Regulated
# RGS105    -0.80070821 Unico    Down Regulated
# BPNT15    -0.37848452 Unico    Down Regulated
# RFWD25    -0.66757866 Unico    Down Regulated
# HLA-DRA5  -1.05017513 Unico    Down Regulated
# CENPK5     0.39724720 Unico    Down Regulated
# WEE15     -1.06170296 Unico    Down Regulated
# IARS6     -0.48901218 Unico    Down Regulated
# MDFIC5    -1.28154528 Unico    Down Regulated
# HLA-DMB5  -0.80872993 Unico    Down Regulated
# PSMC25    -0.60629448 Unico    Down Regulated
# HLA-DRB65 -0.85976125 Unico    Down Regulated

# %%
rp = ggplot(reg.plot.df, aes(x=DE.type, y=beta, fill = method)) + 
     geom_beeswarm(aes(DE.type, y = beta, fill = method, colour = method),
                   priority = 'density', cex = 0.3, #point space
                   side = -1, dodge.width = 0.8, size = 1.5, colour = "black", #dot border 
                   pch = 21, shape = 22, stroke = 0, show.legend = F) +

     geom_half_boxplot(aes(fill = method), side = 'r', color = 'black', 
                       outlier.size = NA, outlier.color = NA, notchwidth = 0.5, size = 0.7, #thickness of the line 
                       width = 0.6, position = position_dodge(0.8), alpha = 1) +  
     geom_hline(yintercept=0, linetype='dotted', col = "black", size=1) + 
    
    
     scale_fill_manual(values = as.character(method.colors[levels(reg.plot.df$method)]), name=NULL) +  
     coord_cartesian(ylim = c(-60,1.25)) + # for annotation to have space
     #scale_y_continuous(trans = "exp") + 
     scale_y_continuous(breaks = c(-1, -0.25, 0, 0.25, 1),
                        trans = scales::pseudo_log_trans(sigma = 0.025)) + 
     scale_x_discrete(labels=c("Down Regulated" = "CREBBP down-regulated genes \n (lower is better)", 
                               "Up Regulated"   = "CREBBP up-regulated genes \n (higher is better)")) +

     ylab("Estimated effect size") + 
     ggtitle("")  + 
     #ggtitle("CREBBP Mutation")  + 

     theme_classic() + # later operation will overide this
     theme(plot.title = element_text(hjust = 0.5, size = title.size, face="bold")) + 
     # label size
     theme(axis.title.x = element_blank()) + 
     theme(axis.title.y = element_text(size = lab.size + 5, face="bold")) + 
     #ticks size
     theme(axis.text.y = element_text(size = lab.size, face="bold")) +
     theme(axis.text.x = element_text(size = lab.size, face="bold"))+
     theme(legend.text = element_text(size = lab.size, face="bold"))
# Out:
# Warning message:
# “Duplicated aesthetics after name standardisation: shape”

# %%
options(repr.plot.width = 16, repr.plot.height = 6, repr.plot.res = 150)
rp
# Out:
# plot without title

# %%
h.loc  = linspace(0.665, 1.33, 6)
v.loc  = -exp(linspace(0.8, 4.00, 5))
v.size = -(exp(linspace(0.45, 1.8, 5))-1)
p.size = 4.5

df1 <- data.frame(a = c(h.loc[1],           h.loc[1], h.loc[6], h.loc[6]), 
                  b = c(v.loc[1]-v.size[1], v.loc[1], v.loc[1], v.loc[1]-v.size[1]))

df2 <- data.frame(a = c(h.loc[2],           h.loc[2], h.loc[6], h.loc[6]), 
                  b = c(v.loc[2]-v.size[2], v.loc[2], v.loc[2], v.loc[2]-v.size[2]))

df3 <- data.frame(a = c(h.loc[3],           h.loc[3], h.loc[6], h.loc[6]), 
                  b = c(v.loc[3]-v.size[3], v.loc[3], v.loc[3], v.loc[3]-v.size[3]))

df4 <- data.frame(a = c(h.loc[4],           h.loc[4], h.loc[6], h.loc[6]), 
                  b = c(v.loc[4]-1.5 * v.size[4], v.loc[4], v.loc[4], v.loc[4]-1.5 * v.size[4]))

df5 <- data.frame(a = c(h.loc[5],           h.loc[5], h.loc[6], h.loc[6]), 
                  b = c(v.loc[5]-2 * v.size[5], v.loc[5], v.loc[5], v.loc[5]-2 * v.size[5]))


df6  <- data.frame(a = df1$a + 1, b = df1$b)
df7  <- data.frame(a = df2$a + 1, b = df2$b)
df8  <- data.frame(a = df3$a + 1, b = df3$b)
df9  <- data.frame(a = df4$a + 1, b = df4$b)
df10 <- data.frame(a = df5$a + 1, b = df5$b)


rp = rp + geom_line(data = df1, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df2, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df3, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df4, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df5, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df6, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df7, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df8, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df9, aes(x = a, y = b), inherit.aes = FALSE) +
          geom_line(data = df10,aes(x = a, y = b), inherit.aes = FALSE) +

          annotate("text", x = (h.loc[1]+ h.loc[6])/2,       y = v.loc[1] + 1.5*v.size[1],      label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.dec["TCAx", "Baseline"],   digits = 1)), parse=TRUE, size = p.size) + 
          annotate("text", x = (h.loc[2]+ h.loc[6])/2,       y = v.loc[2] + 1.5*v.size[2],      label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.dec["TCAx", "CIBERSORTx"], digits = 1)), parse=TRUE, size = p.size) + 
          annotate("text", x = (h.loc[3]+ h.loc[6])/2,       y = v.loc[3] + 2.0*v.size[3],      label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.dec["TCAx", "TCA"],        digits = 1)), parse=TRUE, size = p.size) +
          annotate("text", x = (h.loc[4]+ h.loc[6])/2,       y = v.loc[4] + 2.5*v.size[4],      label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.dec["TCAx", "Bulk"],       digits = 1)), parse=TRUE, size = p.size) +
          annotate("text", x = (h.loc[5]+ h.loc[6])/2,       y = v.loc[5] + 2.5*v.size[5],      label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.dec["TCAx", "bMIND"],      digits = 1)), parse=TRUE, size = p.size) +

          annotate("text", x = 1 + (h.loc[1]+ h.loc[6])/2,   y = (v.loc[1] + 1.5*v.size[1]),    label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.inc["TCAx", "Baseline"],   digits = 1)), parse=TRUE, size = p.size) + 
          annotate("text", x = 1 + (h.loc[2]+ h.loc[6])/2,   y = (v.loc[2] + 1.5*v.size[2]),    label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.inc["TCAx", "CIBERSORTx"], digits = 1)), parse=TRUE, size = p.size) + 
          annotate("text", x = 1 + (h.loc[3]+ h.loc[6])/2,   y = (v.loc[3] + 2.0*v.size[3]),    label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.inc["TCAx", "TCA"],        digits = 1)), parse=TRUE, size = p.size) +
          annotate("text", x = 1 + (h.loc[4]+ h.loc[6])/2,   y = (v.loc[4] + 2.5*v.size[4]),    label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.inc["TCAx", "Bulk"],       digits = 1)), parse=TRUE, size = p.size) +
          annotate("text", x = 1 + (h.loc[5]+ h.loc[6])/2,   y = (v.loc[5] + 2.5*v.size[5]),    label = paste0("\'P = \'~", scientific_pvals_10x(reg.pvals.inc["TCAx", "bMIND"],      digits = 1)), parse=TRUE, size = p.size) #+

# %%
reg.pvals.dec
# Out:
#            Bulk         Baseline     CIBERSORTx   TCA          TCAx
# Bulk       1.000000e+00 1.919463e-04 1.592415e-01 4.853421e-01 1.0000000
# Baseline   9.998088e-01 1.000000e+00 9.862919e-01 9.956841e-01 1.0000000
# CIBERSORTx 8.410167e-01 1.374544e-02 1.000000e+00 8.033852e-01 0.9999992
# TCA        5.150826e-01 4.329413e-03 1.969101e-01 1.000000e+00 0.9999768
# TCAx       5.129824e-10 1.466165e-12 8.527769e-07 2.332466e-05 1.0000000
# bMIND      1.657867e-01 2.097667e-04 5.162937e-02 1.085904e-01 0.9999997
# bMIND.log  9.032524e-11 5.937127e-12 6.781794e-07 3.189442e-07 0.4866162
#            bMIND        bMIND.log
# Bulk       8.344784e-01 1.0000000
# Baseline   9.997911e-01 1.0000000
# CIBERSORTx 9.484832e-01 0.9999993
# TCA        8.916079e-01 0.9999997
# TCAx       2.528761e-07 0.5138085
# bMIND      1.000000e+00 1.0000000
# bMIND.log  5.431867e-15 1.0000000

# %%
options(repr.plot.width = 16, repr.plot.height = 6, repr.plot.res = 150)
rp
# Out:
# plot without title

# %% [markdown]
# # multi plot

# %%
CREBBP.supp.g = egg::ggarrange(plots=list(wp,tp),  
                               labels = c("a", "b"), 
                               align = "h",
                               widths = c(2.5,9),  
                               label.args = list(gp = grid::gpar(font = 30, cex =3)), 
                               debug=F)

# #doesnt align that well the y axis
# CREBBP.supp.g = ggarrange(wp,tp,
#                           nrow = 1, 
#                           widths = c(2.5,9), 
#                           labels = c("a", "b"), 
#                           font.label = list(size = 30, color = "black", face = "bold", family = NULL))
# Out:
# Bin width defaults to 1/30 of the range of the data. Pick better value with
# `binwidth`.
# plot without title

# %%
options(repr.plot.width = 16, repr.plot.height = 7, repr.plot.res = 150)
CREBBP.supp.g
# Out:
# plot without title

# %%
ggsave(file.path(figure.dir, "CREBBP.supp.multi.pdf"), CREBBP.supp.g,
       bg = 'white',
       device = "pdf", width = 16, height = 7, dpi = 600)

# %% [markdown]
# # save

# %%
fig.list = list(w.g = wp, 
                de.g = tp, 
                regress.g = rp)

stats.list = list(w.df = W.df,
                  de.plot.df = de.plot.df, 
                  reg.plot.df = reg.plot.df)


saveRDS(fig.list,   file.path(figure.dir, paste0("CREBBP_fig.list.rds")))
saveRDS(stats.list, file.path(figure.dir, paste0("CREBBP_stats.list.rds")))

# %%
# # DE Main figure

# main.methods.plot = c("CIBERSORTx","TCA", "Unico")
# main.plot.df = de.plot.df[de.plot.df$method %in% main.methods.plot, ]
# main.plot.df$method = factor(main.plot.df$method, levels = main.methods.plot)

# main.plot.df

# title.size = 20
# lab.size = 15

# mp = ggplot(main.plot.df, aes(x=DE.type, y=diff, fill = method)) + 
#      geom_beeswarm(aes(DE.type, y = diff, fill = method, colour = method),
#                    priority = 'density',
#                    side = -1, dodge.width = 0.99, cex = 0.25,  size = 1.75, colour = "black", #dot border 
#                    pch = 21, shape = 22, stroke = 0, show.legend = F) +

#      geom_half_boxplot(aes(fill = method), side = 'r', color = 'black', 
#                        outlier.size = NA, outlier.color = NA, notchwidth = 0.5, size = 0.7, #thickness of the line 
#                        width = 0.6, position = position_dodge(0.99), alpha = 1) +  
#      geom_hline(yintercept=0, linetype='dotted', col = 'grey', size=1) + 
    
    
#      scale_fill_manual(values = method.colors[main.methods.plot], name=NULL) +  
#      coord_cartesian(ylim = c(-8,8)) + # for annotation to have space
#      scale_y_continuous(breaks = c(-4, -2, -1, 0, 1, 2, 4),
#                         trans = scales::pseudo_log_trans(sigma = 0.25)) + 
#      scale_x_discrete(labels=c("Down Regulated" = "MT down genes \n (Green et al., 2015)", 
#                                "Up Regulated"= "MT up genes \n (Green et al., 2015)")) + 
#      ylab(expression(atop("Differences in "*Log[2]*" Expression", "(Deconvolution B cells)"))) + 
#      #ggtitle("CREBBP Mutation")  + 
#      ggtitle("")  + 

#      theme_classic() + # later operation will overide this
#      theme(plot.title = element_text(hjust = 0.5, size = title.size, face="bold")) + 
#      # label size
#      theme(axis.title.x = element_blank()) + 
#      theme(axis.title.y = element_text(size = title.size - 2)) + 
#      #ticks size
#      theme(axis.text.y = element_text(size = lab.size  , face="bold")) +
#      theme(axis.text.x = element_text(size = lab.size + 5, face="bold"))+
#      theme(legend.text = element_text(size=lab.size ))

# options(repr.plot.width = 9, repr.plot.height = 6, repr.plot.res = 150)
# mp



# h.loc  = linspace(0.68, 1.32, 3)
# v.loc  = exp(linspace(0.25, 1.25, 2))  
# v.size = linspace(0.5, 1, 2)
# p.size = 5

# df1 <- data.frame(a = c(h.loc[1],           h.loc[1], h.loc[3], h.loc[3]), 
#                   b = c(v.loc[1]-v.size[1], v.loc[1], v.loc[1], v.loc[1]-v.size[1]))

# df2 <- data.frame(a = c(h.loc[2],           h.loc[2], h.loc[3], h.loc[3]), 
#                   b = c(v.loc[2]-v.size[2], v.loc[2], v.loc[2], v.loc[2]-v.size[2]))



# df3 <- data.frame(a = 1 + (c(h.loc[1],           h.loc[1], h.loc[3], h.loc[3])), 
#                   b = c(-v.loc[1]+v.size[1], -v.loc[1], -v.loc[1], -v.loc[1]+v.size[1]))

# df4 <- data.frame(a = 1 + (c(h.loc[2],           h.loc[2], h.loc[3], h.loc[3])), 
#                   b = c(-v.loc[2]+v.size[2], -v.loc[2], -v.loc[2], -v.loc[2]+v.size[2]))


# mp =  mp + geom_line(data = df1, aes(x = a, y = b), inherit.aes = FALSE) +
#           geom_line(data = df2, aes(x = a, y = b), inherit.aes = FALSE) +
     
       
#           geom_line(data = df3, aes(x = a, y = b), inherit.aes = FALSE) +
#           geom_line(data = df4, aes(x = a, y = b), inherit.aes = FALSE) +
        
#           annotate("text", x = (h.loc[1]+ h.loc[3])/2,       y = v.loc[1] + v.size[1],      label = parse(text = paste0("\'P = \'~", scientific_pvals_10x(pvals.dec["TCAx", "CIBERSORTx"],   digits = 1))), size = p.size) + 
#           annotate("text", x = (h.loc[2]+ h.loc[3])/2,       y = v.loc[2] + v.size[2],      label = parse(text = paste0("\'P = \'~", scientific_pvals_10x(pvals.dec["TCAx", "TCA"], digits = 1))), size = p.size) + 
       
#           annotate("text", x = 1 + (h.loc[1]+ h.loc[3])/2,   y = -(v.loc[1] + v.size[1]),    label = parse(text = paste0("\'P = \'~", scientific_pvals_10x(pvals.inc["TCAx", "CIBERSORTx"],   digits = 1))), size = p.size) + 
#           annotate("text", x = 1 + (h.loc[2]+ h.loc[3])/2,   y = -(v.loc[2] + v.size[2]),    label = parse(text = paste0("\'P = \'~", scientific_pvals_10x(pvals.inc["TCAx", "TCA"], digits = 1))), size = p.size) 
        

# options(repr.plot.width = 10, repr.plot.height = 5, repr.plot.res = 150)
# mp
# # ggsave(file.path(figure.dir, "CREBBP.main.DE.box.png"), device = "png", width = 10, height = 5, dpi = 600)

# # save related ggplots and stats

# %%
# fig.list = list(main.g = mp, 
#                 w.g = wp, 
#                 de.g = p, 
#                 regress.g = rp)

# stats.list = list(main.df = main.plot.df,
#                   w.df = W.df,
#                   de.plot.df = de.plot.df, 
#                   reg.plot.df = reg.plot.df)


# saveRDS(fig.list,   file.path(figure.dir, paste0("CREBBP_fig.list.rds")))
# saveRDS(stats.list, file.path(figure.dir, paste0("CREBBP_stats.list.rds")))

# %%
# # Histogram 

# library(see)

# ggplot(reg.plot.df, aes(x=DE.type, y=beta, fill = method)) + 
#      geom_boxplot(aes(fill = method), side = 'r', color = 'black', 
#                        outlier.size = NA, outlier.color = NA, notchwidth = 0.5, size = 0.7, #thickness of the line 
#                        width = 0.6, position = position_dodge(0.8), alpha = 1) +  
#      geom_hline(yintercept=0, linetype='dotted', col = "black", size=1) + 
    
    
#      scale_fill_manual(values = as.character(method.colors[levels(reg.plot.df$method)]), name=NULL) +  
#      #coord_cartesian(ylim = c(-60,1.25)) + # for annotation to have space
#      #scale_y_continuous(trans = "exp") + 
#      #scale_y_continuous(breaks = c(-1, -0.25, 0, 0.25, 1),
#      #                   trans = scales::pseudo_log_trans(sigma = 0.01)) + 
#      scale_x_discrete(labels=c("Down Regulated" = "CREBBP down-regulated genes \n (lower is better)", 
#                                "Up Regulated"   = "CREBBP up-regulated genes \n (higher is better)")) +

#      ylab(expression(atop("Estimated effect size", "on mutation status"))) + 
#      ggtitle("")  + 
#      #ggtitle("CREBBP Mutation")  + 

#      theme_classic() + # later operation will overide this
#      theme(plot.title = element_text(hjust = 0.5, size = title.size, face="bold")) + 
#      # label size
#      theme(axis.title.x = element_blank()) + 
#      theme(axis.title.y = element_text(size = lab.size + 2, face="bold")) + 
#      #ticks size
#      theme(axis.text.y = element_text(size = lab.size, face="bold")) +
#      theme(axis.text.x = element_text(size = lab.size, face="bold"))+
#      theme(legend.text = element_text(size = lab.size, face="bold"))

# bMIND.betas.dec = reg.plot.df[reg.plot.df$method == "bMIND" & reg.plot.df$"DE.type" == "Down Regulated", "beta"]
# tcax.betas.dec  = reg.plot.df[reg.plot.df$method == "Unico" & reg.plot.df$"DE.type" == "Down Regulated", "beta"]

# boxplot.stats(tcax.betas.dec)

# min(max(tcax.betas.dec), quantile(tcax.betas.dec, 0.75) + 1.5 * IQR(tcax.betas.dec))

# max(min(tcax.betas.dec), quantile(tcax.betas.dec, 0.25) - 1.5 * IQR(tcax.betas.dec))

# median(tcax.betas.dec)

# median(bMIND.betas.dec)

# tmp.df = reg.plot.df[reg.plot.df$"method" %in% c("Unico", "bMIND") & reg.plot.df$"DE.type" == "Down Regulated",]

# tmp.df

# mu <- ddply(tmp.df, "method", summarise, grp.mean=median(beta))
# tmp.g = ggplot(tmp.df, aes(x=beta, color=method, fill=method)) +
#         geom_histogram(aes(y=..density..), position="identity", alpha=0.5, bins=100)+
#         geom_density(alpha=0.2)+
#         geom_vline(data=mu, aes(xintercept=grp.mean, color=method),linetype="dashed")+
#         scale_color_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
#         scale_fill_manual(values=c("#999999", "#E69F00", "#56B4E9"))+
#         scale_x_continuous(breaks = c(-1, -0.25, 0, 0.25, 1),
#                            trans = scales::pseudo_log_trans(sigma = 0.01)) + 
     
#         theme_classic()

# options(repr.plot.width = 10, repr.plot.height = 5, repr.plot.res = 150)
# tmp.g
