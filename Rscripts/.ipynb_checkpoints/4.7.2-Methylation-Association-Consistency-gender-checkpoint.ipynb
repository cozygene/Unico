# %%
library("rlang") #duplicate
set.seed(2023)

# %%
data.names  = c("liu", "hannum", "hannon1", "hannon2")
source.ids = c("Gran", "CD4T", "CD8T", "Mono", "B", "NK")

results_dir = "/u/project/halperin/johnsonc/TCAx/TCAx2023/Result/Methylation/Consistency/XY/"
if (!file.exists(results_dir)){
     print("check results_dir")
}

# %% [markdown]
# # Load pvals, coeffs

# %%
pheno = "gender"

# %%
pval.list.file  = file.path(results_dir, paste0(pheno,".pval.list"))
coeff.list.file = file.path(results_dir, paste0(pheno,".coeff.list"))

pval.list  = readRDS(pval.list.file)
coeff.list = readRDS(coeff.list.file)

# %%
str(pval.list$liu)
# Out:
# List of 28
#  $ TCAx.parametric.full.marginal    : num [1:153155, 1:6] 0.4868 0.0894 0.8117 0.3003 0.4536 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCAx.parametric.full.joint       : num [1:153155, 1] 0.358662 0.020667 0.000645 0.228034 0.144714 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCAx.parametric.X2.marginal      : num [1:153155, 1:6] 0.893 0.279 0.509 0.149 0.57 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCAx.parametric.X2.joint         : num [1:153155, 1] 0.25554 0.06079 0.00313 0.02399 0.12585 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCAx.parametric.Q2.marginal      : num [1:153155, 1:6] 0.535 0.115 0.651 0.391 0.711 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCAx.parametric.Q2.joint         : num [1:153155, 1] 0.48476 0.02094 0.00114 0.25173 0.12449 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCAx.parametric.XQ2.marginal     : num [1:153155, 1:6] 0.885 0.205 0.405 0.14 0.857 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCAx.parametric.XQ2.joint        : num [1:153155, 1] 0.383318 0.000911 0.002059 0.149356 0.045052 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCAx.parametric.X2Q2.marginal    : num [1:153155, 1:6] 0.677 0.478 0.318 0.306 0.938 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCAx.parametric.X2Q2.joint       : num [1:153155, 1] 0.29562 0.04511 0.00379 0.08284 0.32928 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCA.parametric.full.marginal     : num [1:153155, 1:6] 0.676 0.107 0.843 0.102 0.482 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCA.parametric.full.joint        : num [1:153155, 1] 0.618945 0.038435 0.000837 0.249928 0.098849 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCA.parametric.X2.marginal       : num [1:153155, 1:6] 0.9505 0.2905 0.5683 0.0476 0.5887 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCA.parametric.X2.joint          : num [1:153155, 1] 0.22647 0.08482 0.00512 0.1038 0.13548 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCA.parametric.Q2.marginal       : num [1:153155, 1:6] 0.7797 0.1736 0.6413 0.0913 0.9546 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCA.parametric.Q2.joint          : num [1:153155, 1] 0.52205 0.04782 0.00413 0.22267 0.06133 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCA.parametric.XQ2.marginal      : num [1:153155, 1:6] 0.7173 0.3791 0.5801 0.0528 0.9571 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCA.parametric.XQ2.joint         : num [1:153155, 1] 0.47131 0.02836 0.00681 0.31116 0.01299 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ TCA.parametric.X2Q2.marginal     : num [1:153155, 1:6] 0.8044 0.4927 0.3582 0.0714 0.7665 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ TCA.parametric.X2Q2.joint        : num [1:153155, 1] 0.48725 0.09013 0.00291 0.22415 0.17948 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ CellDMC.parametric.full.marginal : num [1:153155, 1:6] 0.59 0.204 0.919 0.176 0.429 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ CellDMC.parametric.full.joint    : num [1:153155, 1] 0.41077 0.02015 0.00121 0.70571 0.12244 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ CellDMC.parametric.X2.marginal   : num [1:153155, 1:6] 0.8478 0.3826 0.6539 0.0624 0.5786 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ CellDMC.parametric.X2.joint      : num [1:153155, 1] 0.16283 0.0319 0.00769 0.01832 0.10427 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ Baseline.parametric.full.marginal: num [1:153155, 1:6] 0.16568 0.000515 0.00031 0.725434 0.993838 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ Baseline.parametric.full.joint   : num [1:153155, 1] 0.273812 0.006296 0.000525 0.377813 0.651823 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"
#  $ Baseline.parametric.X2.marginal  : num [1:153155, 1:6] 1.24e-02 1.44e-05 1.51e-04 9.34e-01 9.59e-01 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr [1:6] "Gran.gender" "CD4T.gender" "CD8T.gender" "Mono.gender" ...
#  $ Baseline.parametric.X2.joint     : num [1:153155, 1] 0.10322 0.00325 0.00167 0.31307 0.74456 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:153155] "cg00001349" "cg00002837" "cg00003287" "cg00008647" ...
#   .. ..$ : chr "gender"

# %% [markdown]
# # Testing

# %%
get_confusion_df = function(dis_pvals_mat, val_pvals_mat,
                            dis_coeffs_mat, val_coeffs_mat,
                            sig_thr,  dis_sig_mode,  val_sig_mode,
                            null_thr, dis_null_mode, val_null_mode, verbose = F){
    
    message(paste("discovery shape: ", dim(dis_pvals_mat)[1], dim(dis_pvals_mat)[2]))
    message(paste("validation shape: ", dim(val_pvals_mat)[1], dim(val_pvals_mat)[2])) 
     
    keep.probs     = intersect(rownames(dis_pvals_mat), rownames(val_pvals_mat))
    dis_pvals_mat  = duplicate(dis_pvals_mat)[keep.probs, , drop = F]
    dis_coeffs_mat = duplicate(dis_coeffs_mat)[keep.probs, , drop = F]
    val_pvals_mat  = duplicate(val_pvals_mat)[keep.probs, , drop = F]
    val_coeffs_mat = duplicate(val_coeffs_mat)[keep.probs, , drop = F]
    
    message("after")
    message(paste("discovery shape: ", dim(dis_pvals_mat)[1], dim(dis_pvals_mat)[2]))
    message(paste("validation shape: ", dim(val_pvals_mat)[1], dim(val_pvals_mat)[2])) 
    message("###################")
    
    #Positive
    if (dis_sig_mode == "strict"){
        dis_sig_thr = sig_thr/(dim(dis_pvals_mat)[1] * dim(dis_pvals_mat)[2])
    }else if (dis_sig_mode == "unadjust"){
        dis_sig_thr = sig_thr
    }else{
        print("error")
    }
    if(verbose){print(paste0("dis_sig_thr: ",  dis_sig_thr))}

    dis_sig_mask = dis_pvals_mat < dis_sig_thr
    n_ds = sum(dis_sig_mask)
    if(verbose){print(paste0("n_ds: ",  n_ds))}

    if (val_sig_mode == "strict"){
        val_sig_thr = sig_thr/(dim(val_pvals_mat)[1] * dim(val_pvals_mat)[2])
    }else if (val_sig_mode == "loose"){
        val_sig_thr = sig_thr/n_ds
    }else if (val_sig_mode == "unadjust"){
        val_sig_thr = sig_thr
    }else{
        print("error")
    }
    if(verbose){print(paste0("val_sig_thr: ",  val_sig_thr))}
    
    val_sig_mask_pvals = val_pvals_mat[dis_sig_mask] < val_sig_thr
    print("val_sig_mask_pvals")
    print(sum(val_sig_mask_pvals))
    
    val_sig_mask_ceoffs = sign(val_coeffs_mat[dis_sig_mask]) == sign(dis_coeffs_mat[dis_sig_mask]) 
    print("val_sig_mask_ceoffs")
    print(sum(val_sig_mask_ceoffs))
    val_sig_mask = val_sig_mask_pvals & val_sig_mask_ceoffs
    TP = sum(val_sig_mask)
    FN = sum(!val_sig_mask)


    # Negative
    if (dis_null_mode == "strict"){
        print("error")
    }else if (dis_null_mode == "unadjust"){
        dis_null_thr = null_thr
    }else{
        print("error")
    }
    if(verbose){print(paste0("dis_null_thr: ",  dis_null_thr))}

    dis_null_mask = dis_pvals_mat > dis_null_thr

    n_dn = sum(dis_null_mask)
    if(verbose){print(paste0("n_dn: ",  n_dn))}

    if (val_null_mode == "strict"){
        print("error")
    }else if (val_null_mode == "loose"){
        val_null_thr = sig_thr/n_dn
    }else if (val_null_mode == "unadjust"){
        val_null_thr = sig_thr
    }else{
        print("error")
    }
    if(verbose){print(paste0("val_null_thr: ",  val_null_thr))}

    val_null_mask = val_pvals_mat[dis_null_mask] > val_null_thr 

    FP = sum(!val_null_mask)
    TN = sum(val_null_mask)   
    
    recall    = TP/(TP + FN)
    precision = TP/(TP + FP)
    specificity = TN/(TN + FP)
    F1        = 1/(0.5 * (1/recall + 1/precision))
    accuracy = (TP + TN)/(TP + FP + TN + FN)
    TP = as.numeric(TP)
    TN = as.numeric(TN)
    FP = as.numeric(FP)
    FN = as.numeric(FN)
    MCC = as.numeric((TP*TN) - (FP*FN))/ sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    
    confusion_df = data.frame(TP = TP, 
                              FN = FN, 
                              FP = FP, 
                              TN = TN, 
                              recall = recall, 
                              precision = precision, 
                              F1 = F1,
                              specificity = specificity,
                              accuracy = accuracy,
                              MCC = MCC)
    return(confusion_df)
}

#loop through each method
get_confusion_dfs =function(methods, 
                            dis_pvals_mats, val_pvals_mats,
                            dis_coeffs_mats, val_coeffs_mats,
                            sig_thr,  dis_sig_mode,  val_sig_mode,
                            null_thr, dis_null_mode, val_null_mode, verbose = F){
    confusion_dfs = c()
    for (method in methods){
        print(method)
        confusion_df = get_confusion_df(dis_pvals_mats[[method]], val_pvals_mats[[method]],
                                        dis_coeffs_mats[[method]], val_coeffs_mats[[method]],
                                        sig_thr,  dis_sig_mode,  val_sig_mode,
                            null_thr, dis_null_mode, val_null_mode, verbose = verbose)
        rownames(confusion_df) = c(method)
        confusion_dfs = rbind(confusion_dfs, confusion_df)
    }
    return(confusion_dfs)
}

#loop through both direction 
get_bidir_confusion_dfs = function(methods, 
                                   pvals_mats, coeffs_mats, 
                                   sig_thr,  dis_sig_mode,  val_sig_mode,
                                   null_thr, dis_null_mode, val_null_mode, verbose = F){
    
    
    
    bidir_confusion_dfs = list()

    bidir_confusion_dfs[["forward"]] = get_confusion_dfs(methods,
                                                         #dataset 1.      # dataset 2
                                                         pvals_mats[[1]], pvals_mats[[2]],
                                                         coeffs_mats[[1]], coeffs_mats[[2]],
                                                         sig_thr,  dis_sig_mode,  val_sig_mode,
                                                         null_thr, dis_null_mode, val_null_mode, verbose = verbose)
    bidir_confusion_dfs[["backward"]] = get_confusion_dfs(methods,
                                                          pvals_mats[[2]], pvals_mats[[1]],
                                                          coeffs_mats[[2]], coeffs_mats[[1]],
                                                          sig_thr,  dis_sig_mode,  val_sig_mode,
                                                          null_thr, dis_null_mode, val_null_mode, verbose = verbose)
    return(bidir_confusion_dfs)
}

# %%
methods = c()
for (data.name in names(pval.list)){
    methods = c(methods, list(names(pval.list[[data.name]])))
}
methods = Reduce(intersect, methods)
print("methods with result on all 4 datasets")
print(methods)
# Out:
# [1] "methods with result on all 4 datasets"
#  [1] "TCAx.parametric.full.marginal"     "TCAx.parametric.full.joint"
#  [3] "TCAx.parametric.X2.marginal"       "TCAx.parametric.X2.joint"
#  [5] "TCAx.parametric.Q2.marginal"       "TCAx.parametric.Q2.joint"
#  [7] "TCAx.parametric.XQ2.marginal"      "TCAx.parametric.XQ2.joint"
#  [9] "TCAx.parametric.X2Q2.marginal"     "TCAx.parametric.X2Q2.joint"
# [11] "TCA.parametric.full.marginal"      "TCA.parametric.full.joint"
# [13] "TCA.parametric.X2.marginal"        "TCA.parametric.X2.joint"
# [15] "TCA.parametric.Q2.marginal"        "TCA.parametric.Q2.joint"
# [17] "TCA.parametric.XQ2.marginal"       "TCA.parametric.XQ2.joint"
# [19] "TCA.parametric.X2Q2.marginal"      "TCA.parametric.X2Q2.joint"
# [21] "CellDMC.parametric.full.marginal"  "CellDMC.parametric.full.joint"
# [23] "CellDMC.parametric.X2.marginal"    "CellDMC.parametric.X2.joint"
# [25] "Baseline.parametric.full.marginal" "Baseline.parametric.full.joint"
# [27] "Baseline.parametric.X2.marginal"   "Baseline.parametric.X2.joint"

# %%
bidir_confusion_dfs_list = list()
for (i in 1:length(data.names)){
    for(j in i:length(data.names)){
        print(paste0(data.names[i],".", data.names[j]))
        bidir_confusion_dfs = get_bidir_confusion_dfs(methods = methods,
                                                      pvals_mats = list(pval.list[[i]], pval.list[[j]]),
                                                      coeffs_mats = list(coeff.list[[i]], coeff.list[[j]]),
                                                      sig_thr  = 0.05, dis_sig_mode  = "strict", val_sig_mode = "loose",
                                                      null_thr = 0.95, dis_null_mode = "unadjust", val_null_mode = "loose", verbose = T)
        bidir_confusion_dfs_list[[paste0(data.names[i],".", data.names[j])]] = bidir_confusion_dfs
    }
}
# Out:
# [1] "liu.liu"
# [1] "TCAx.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 80"
# [1] "val_sig_thr: 0.000625"
# [1] "val_sig_mask_pvals"
# [1] 80
# [1] "val_sig_mask_ceoffs"
# [1] 80
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 44734"
# [1] "val_null_thr: 1.11771806679483e-06"
# [1] "TCAx.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1098"
# [1] "val_sig_thr: 4.55373406193078e-05"
# [1] "val_sig_mask_pvals"
# [1] 1098
# [1] "val_sig_mask_ceoffs"
# [1] 1098
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5346"
# [1] "val_null_thr: 9.35278713056491e-06"
# [1] "TCAx.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 62"
# [1] "val_sig_thr: 0.000806451612903226"
# [1] "val_sig_mask_pvals"
# [1] 62
# [1] "val_sig_mask_ceoffs"
# [1] 62
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 44247"
# [1] "val_null_thr: 1.13002011435804e-06"
# [1] "TCAx.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 992"
# [1] "val_sig_thr: 5.04032258064516e-05"
# [1] "val_sig_mask_pvals"
# [1] 992
# [1] "val_sig_mask_ceoffs"
# [1] 992
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5400"
# [1] "val_null_thr: 9.25925925925926e-06"
# [1] "TCAx.parametric.Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 61"
# [1] "val_sig_thr: 0.000819672131147541"
# [1] "val_sig_mask_pvals"
# [1] 61
# [1] "val_sig_mask_ceoffs"
# [1] 61
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 45150"
# [1] "val_null_thr: 1.10741971207087e-06"
# [1] "TCAx.parametric.Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 953"
# [1] "val_sig_thr: 5.24658971668416e-05"
# [1] "val_sig_mask_pvals"
# [1] 953
# [1] "val_sig_mask_ceoffs"
# [1] 953
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5709"
# [1] "val_null_thr: 8.75810124365038e-06"
# [1] "TCAx.parametric.XQ2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 60"
# [1] "val_sig_thr: 0.000833333333333333"
# [1] "val_sig_mask_pvals"
# [1] 60
# [1] "val_sig_mask_ceoffs"
# [1] 60
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 44470"
# [1] "val_null_thr: 1.12435349673937e-06"
# [1] "TCAx.parametric.XQ2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 980"
# [1] "val_sig_thr: 5.10204081632653e-05"
# [1] "val_sig_mask_pvals"
# [1] 980
# [1] "val_sig_mask_ceoffs"
# [1] 980
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5383"
# [1] "val_null_thr: 9.28850083596508e-06"
# [1] "TCAx.parametric.X2Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 60"
# [1] "val_sig_thr: 0.000833333333333333"
# [1] "val_sig_mask_pvals"
# [1] 60
# [1] "val_sig_mask_ceoffs"
# [1] 60
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 45059"
# [1] "val_null_thr: 1.10965622850041e-06"
# [1] "TCAx.parametric.X2Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 876"
# [1] "val_sig_thr: 5.70776255707763e-05"
# [1] "val_sig_mask_pvals"
# [1] 876
# [1] "val_sig_mask_ceoffs"
# [1] 876
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5450"
# [1] "val_null_thr: 9.17431192660551e-06"
# [1] "TCA.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 108"
# [1] "val_sig_thr: 0.000462962962962963"
# [1] "val_sig_mask_pvals"
# [1] 108
# [1] "val_sig_mask_ceoffs"
# [1] 108
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 42271"
# [1] "val_null_thr: 1.18284403018618e-06"
# [1] "TCA.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1200"
# [1] "val_sig_thr: 4.16666666666667e-05"
# [1] "val_sig_mask_pvals"
# [1] 1200
# [1] "val_sig_mask_ceoffs"
# [1] 1200
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4394"
# [1] "val_null_thr: 1.13791533909877e-05"
# [1] "TCA.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 65"
# [1] "val_sig_thr: 0.000769230769230769"
# [1] "val_sig_mask_pvals"
# [1] 65
# [1] "val_sig_mask_ceoffs"
# [1] 65
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43259"
# [1] "val_null_thr: 1.15582884486465e-06"
# [1] "TCA.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1022"
# [1] "val_sig_thr: 4.89236790606654e-05"
# [1] "val_sig_mask_pvals"
# [1] 1022
# [1] "val_sig_mask_ceoffs"
# [1] 1022
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4660"
# [1] "val_null_thr: 1.07296137339056e-05"
# [1] "TCA.parametric.Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 83"
# [1] "val_sig_thr: 0.000602409638554217"
# [1] "val_sig_mask_pvals"
# [1] 83
# [1] "val_sig_mask_ceoffs"
# [1] 83
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43897"
# [1] "val_null_thr: 1.13903000205025e-06"
# [1] "TCA.parametric.Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 989"
# [1] "val_sig_thr: 5.05561172901921e-05"
# [1] "val_sig_mask_pvals"
# [1] 989
# [1] "val_sig_mask_ceoffs"
# [1] 989
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5000"
# [1] "val_null_thr: 1e-05"
# [1] "TCA.parametric.XQ2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 63"
# [1] "val_sig_thr: 0.000793650793650794"
# [1] "val_sig_mask_pvals"
# [1] 63
# [1] "val_sig_mask_ceoffs"
# [1] 63
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43624"
# [1] "val_null_thr: 1.14615807812213e-06"
# [1] "TCA.parametric.XQ2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 972"
# [1] "val_sig_thr: 5.1440329218107e-05"
# [1] "val_sig_mask_pvals"
# [1] 972
# [1] "val_sig_mask_ceoffs"
# [1] 972
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4743"
# [1] "val_null_thr: 1.05418511490618e-05"
# [1] "TCA.parametric.X2Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 55"
# [1] "val_sig_thr: 0.000909090909090909"
# [1] "val_sig_mask_pvals"
# [1] 55
# [1] "val_sig_mask_ceoffs"
# [1] 55
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43370"
# [1] "val_null_thr: 1.1528706479133e-06"
# [1] "TCA.parametric.X2Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 887"
# [1] "val_sig_thr: 5.6369785794814e-05"
# [1] "val_sig_mask_pvals"
# [1] 887
# [1] "val_sig_mask_ceoffs"
# [1] 887
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4966"
# [1] "val_null_thr: 1.00684655658478e-05"
# [1] "CellDMC.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 607"
# [1] "val_sig_thr: 8.23723228995058e-05"
# [1] "val_sig_mask_pvals"
# [1] 607
# [1] "val_sig_mask_ceoffs"
# [1] 607
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 42276"
# [1] "val_null_thr: 1.18270413473366e-06"
# [1] "CellDMC.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1730"
# [1] "val_sig_thr: 2.89017341040462e-05"
# [1] "val_sig_mask_pvals"
# [1] 1730
# [1] "val_sig_mask_ceoffs"
# [1] 1730
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4461"
# [1] "val_null_thr: 1.12082492714638e-05"
# [1] "CellDMC.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 78"
# [1] "val_sig_thr: 0.000641025641025641"
# [1] "val_sig_mask_pvals"
# [1] 78
# [1] "val_sig_mask_ceoffs"
# [1] 78
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43821"
# [1] "val_null_thr: 1.14100545400607e-06"
# [1] "CellDMC.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1171"
# [1] "val_sig_thr: 4.26985482493595e-05"
# [1] "val_sig_mask_pvals"
# [1] 1171
# [1] "val_sig_mask_ceoffs"
# [1] 1171
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5015"
# [1] "val_null_thr: 9.97008973080758e-06"
# [1] "Baseline.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 4757"
# [1] "val_sig_thr: 1.05108261509355e-05"
# [1] "val_sig_mask_pvals"
# [1] 4757
# [1] "val_sig_mask_ceoffs"
# [1] 4757
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 34188"
# [1] "val_null_thr: 1.46250146250146e-06"
# [1] "Baseline.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 2288"
# [1] "val_sig_thr: 2.18531468531469e-05"
# [1] "val_sig_mask_pvals"
# [1] 2288
# [1] "val_sig_mask_ceoffs"
# [1] 2288
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5422"
# [1] "val_null_thr: 9.22168941350055e-06"
# [1] "Baseline.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 4546"
# [1] "val_sig_thr: 1.0998680158381e-05"
# [1] "val_sig_mask_pvals"
# [1] 4546
# [1] "val_sig_mask_ceoffs"
# [1] 4546
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 32683"
# [1] "val_null_thr: 1.52984732123734e-06"
# [1] "Baseline.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 2031"
# [1] "val_sig_thr: 2.46184145741014e-05"
# [1] "val_sig_mask_pvals"
# [1] 2031
# [1] "val_sig_mask_ceoffs"
# [1] 2031
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5479"
# [1] "val_null_thr: 9.12575287461216e-06"
# [1] "TCAx.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 80"
# [1] "val_sig_thr: 0.000625"
# [1] "val_sig_mask_pvals"
# [1] 80
# [1] "val_sig_mask_ceoffs"
# [1] 80
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 44734"
# [1] "val_null_thr: 1.11771806679483e-06"
# [1] "TCAx.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1098"
# [1] "val_sig_thr: 4.55373406193078e-05"
# [1] "val_sig_mask_pvals"
# [1] 1098
# [1] "val_sig_mask_ceoffs"
# [1] 1098
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5346"
# [1] "val_null_thr: 9.35278713056491e-06"
# [1] "TCAx.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 62"
# [1] "val_sig_thr: 0.000806451612903226"
# [1] "val_sig_mask_pvals"
# [1] 62
# [1] "val_sig_mask_ceoffs"
# [1] 62
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 44247"
# [1] "val_null_thr: 1.13002011435804e-06"
# [1] "TCAx.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 992"
# [1] "val_sig_thr: 5.04032258064516e-05"
# [1] "val_sig_mask_pvals"
# [1] 992
# [1] "val_sig_mask_ceoffs"
# [1] 992
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5400"
# [1] "val_null_thr: 9.25925925925926e-06"
# [1] "TCAx.parametric.Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 61"
# [1] "val_sig_thr: 0.000819672131147541"
# [1] "val_sig_mask_pvals"
# [1] 61
# [1] "val_sig_mask_ceoffs"
# [1] 61
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 45150"
# [1] "val_null_thr: 1.10741971207087e-06"
# [1] "TCAx.parametric.Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 953"
# [1] "val_sig_thr: 5.24658971668416e-05"
# [1] "val_sig_mask_pvals"
# [1] 953
# [1] "val_sig_mask_ceoffs"
# [1] 953
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5709"
# [1] "val_null_thr: 8.75810124365038e-06"
# [1] "TCAx.parametric.XQ2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 60"
# [1] "val_sig_thr: 0.000833333333333333"
# [1] "val_sig_mask_pvals"
# [1] 60
# [1] "val_sig_mask_ceoffs"
# [1] 60
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 44470"
# [1] "val_null_thr: 1.12435349673937e-06"
# [1] "TCAx.parametric.XQ2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 980"
# [1] "val_sig_thr: 5.10204081632653e-05"
# [1] "val_sig_mask_pvals"
# [1] 980
# [1] "val_sig_mask_ceoffs"
# [1] 980
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5383"
# [1] "val_null_thr: 9.28850083596508e-06"
# [1] "TCAx.parametric.X2Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 60"
# [1] "val_sig_thr: 0.000833333333333333"
# [1] "val_sig_mask_pvals"
# [1] 60
# [1] "val_sig_mask_ceoffs"
# [1] 60
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 45059"
# [1] "val_null_thr: 1.10965622850041e-06"
# [1] "TCAx.parametric.X2Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 876"
# [1] "val_sig_thr: 5.70776255707763e-05"
# [1] "val_sig_mask_pvals"
# [1] 876
# [1] "val_sig_mask_ceoffs"
# [1] 876
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5450"
# [1] "val_null_thr: 9.17431192660551e-06"
# [1] "TCA.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 108"
# [1] "val_sig_thr: 0.000462962962962963"
# [1] "val_sig_mask_pvals"
# [1] 108
# [1] "val_sig_mask_ceoffs"
# [1] 108
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 42271"
# [1] "val_null_thr: 1.18284403018618e-06"
# [1] "TCA.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1200"
# [1] "val_sig_thr: 4.16666666666667e-05"
# [1] "val_sig_mask_pvals"
# [1] 1200
# [1] "val_sig_mask_ceoffs"
# [1] 1200
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4394"
# [1] "val_null_thr: 1.13791533909877e-05"
# [1] "TCA.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 65"
# [1] "val_sig_thr: 0.000769230769230769"
# [1] "val_sig_mask_pvals"
# [1] 65
# [1] "val_sig_mask_ceoffs"
# [1] 65
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43259"
# [1] "val_null_thr: 1.15582884486465e-06"
# [1] "TCA.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1022"
# [1] "val_sig_thr: 4.89236790606654e-05"
# [1] "val_sig_mask_pvals"
# [1] 1022
# [1] "val_sig_mask_ceoffs"
# [1] 1022
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4660"
# [1] "val_null_thr: 1.07296137339056e-05"
# [1] "TCA.parametric.Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 83"
# [1] "val_sig_thr: 0.000602409638554217"
# [1] "val_sig_mask_pvals"
# [1] 83
# [1] "val_sig_mask_ceoffs"
# [1] 83
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43897"
# [1] "val_null_thr: 1.13903000205025e-06"
# [1] "TCA.parametric.Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 989"
# [1] "val_sig_thr: 5.05561172901921e-05"
# [1] "val_sig_mask_pvals"
# [1] 989
# [1] "val_sig_mask_ceoffs"
# [1] 989
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5000"
# [1] "val_null_thr: 1e-05"
# [1] "TCA.parametric.XQ2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 63"
# [1] "val_sig_thr: 0.000793650793650794"
# [1] "val_sig_mask_pvals"
# [1] 63
# [1] "val_sig_mask_ceoffs"
# [1] 63
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43624"
# [1] "val_null_thr: 1.14615807812213e-06"
# [1] "TCA.parametric.XQ2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 972"
# [1] "val_sig_thr: 5.1440329218107e-05"
# [1] "val_sig_mask_pvals"
# [1] 972
# [1] "val_sig_mask_ceoffs"
# [1] 972
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4743"
# [1] "val_null_thr: 1.05418511490618e-05"
# [1] "TCA.parametric.X2Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 55"
# [1] "val_sig_thr: 0.000909090909090909"
# [1] "val_sig_mask_pvals"
# [1] 55
# [1] "val_sig_mask_ceoffs"
# [1] 55
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43370"
# [1] "val_null_thr: 1.1528706479133e-06"
# [1] "TCA.parametric.X2Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 887"
# [1] "val_sig_thr: 5.6369785794814e-05"
# [1] "val_sig_mask_pvals"
# [1] 887
# [1] "val_sig_mask_ceoffs"
# [1] 887
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4966"
# [1] "val_null_thr: 1.00684655658478e-05"
# [1] "CellDMC.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 607"
# [1] "val_sig_thr: 8.23723228995058e-05"
# [1] "val_sig_mask_pvals"
# [1] 607
# [1] "val_sig_mask_ceoffs"
# [1] 607
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 42276"
# [1] "val_null_thr: 1.18270413473366e-06"
# [1] "CellDMC.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1730"
# [1] "val_sig_thr: 2.89017341040462e-05"
# [1] "val_sig_mask_pvals"
# [1] 1730
# [1] "val_sig_mask_ceoffs"
# [1] 1730
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4461"
# [1] "val_null_thr: 1.12082492714638e-05"
# [1] "CellDMC.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 78"
# [1] "val_sig_thr: 0.000641025641025641"
# [1] "val_sig_mask_pvals"
# [1] 78
# [1] "val_sig_mask_ceoffs"
# [1] 78
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 43821"
# [1] "val_null_thr: 1.14100545400607e-06"
# [1] "CellDMC.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 1171"
# [1] "val_sig_thr: 4.26985482493595e-05"
# [1] "val_sig_mask_pvals"
# [1] 1171
# [1] "val_sig_mask_ceoffs"
# [1] 1171
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5015"
# [1] "val_null_thr: 9.97008973080758e-06"
# [1] "Baseline.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 4757"
# [1] "val_sig_thr: 1.05108261509355e-05"
# [1] "val_sig_mask_pvals"
# [1] 4757
# [1] "val_sig_mask_ceoffs"
# [1] 4757
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 34188"
# [1] "val_null_thr: 1.46250146250146e-06"
# [1] "Baseline.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 2288"
# [1] "val_sig_thr: 2.18531468531469e-05"
# [1] "val_sig_mask_pvals"
# [1] 2288
# [1] "val_sig_mask_ceoffs"
# [1] 2288
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5422"
# [1] "val_null_thr: 9.22168941350055e-06"
# [1] "Baseline.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  153155 6
#
# validation shape:  153155 6
#
# ###################
# [1] "dis_sig_thr: 5.4411108571926e-08"
# [1] "n_ds: 4546"
# [1] "val_sig_thr: 1.0998680158381e-05"
# [1] "val_sig_mask_pvals"
# [1] 4546
# [1] "val_sig_mask_ceoffs"
# [1] 4546
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 32683"
# [1] "val_null_thr: 1.52984732123734e-06"
# [1] "Baseline.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  153155 1
#
# validation shape:  153155 1
#
# ###################
# [1] "dis_sig_thr: 3.26466651431556e-07"
# [1] "n_ds: 2031"
# [1] "val_sig_thr: 2.46184145741014e-05"
# [1] "val_sig_mask_pvals"
# [1] 2031
# [1] "val_sig_mask_ceoffs"
# [1] 2031
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 5479"
# [1] "val_null_thr: 9.12575287461216e-06"
# [1] "liu.hannum"
# [1] "TCAx.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 72"
# [1] "val_sig_thr: 0.000694444444444444"
# [1] "val_sig_mask_pvals"
# [1] 55
# [1] "val_sig_mask_ceoffs"
# [1] 67
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 37755"
# [1] "val_null_thr: 1.32432790358893e-06"
# [1] "TCAx.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1104"
# [1] "val_sig_thr: 4.52898550724638e-05"
# [1] "val_sig_mask_pvals"
# [1] 837
# [1] "val_sig_mask_ceoffs"
# [1] 1104
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4267"
# [1] "val_null_thr: 1.17178345441762e-05"
# [1] "TCAx.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 60"
# [1] "val_sig_thr: 0.000833333333333333"
# [1] "val_sig_mask_pvals"
# [1] 52
# [1] "val_sig_mask_ceoffs"
# [1] 58
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 37248"
# [1] "val_null_thr: 1.34235395189003e-06"
# [1] "TCAx.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1010"
# [1] "val_sig_thr: 4.95049504950495e-05"
# [1] "val_sig_mask_pvals"
# [1] 790
# [1] "val_sig_mask_ceoffs"
# [1] 1010
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4242"
# [1] "val_null_thr: 1.17868929750118e-05"
# [1] "TCAx.parametric.Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 56"
# [1] "val_sig_thr: 0.000892857142857143"
# [1] "val_sig_mask_pvals"
# [1] 49
# [1] "val_sig_mask_ceoffs"
# [1] 53
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 38031"
# [1] "val_null_thr: 1.31471694144251e-06"
# [1] "TCAx.parametric.Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 962"
# [1] "val_sig_thr: 5.1975051975052e-05"
# [1] "val_sig_mask_pvals"
# [1] 755
# [1] "val_sig_mask_ceoffs"
# [1] 962
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4568"
# [1] "val_null_thr: 1.09457092819615e-05"
# [1] "TCAx.parametric.XQ2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 59"
# [1] "val_sig_thr: 0.000847457627118644"
# [1] "val_sig_mask_pvals"
# [1] 51
# [1] "val_sig_mask_ceoffs"
# [1] 59
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 37448"
# [1] "val_null_thr: 1.33518478957488e-06"
# [1] "TCAx.parametric.XQ2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 991"
# [1] "val_sig_thr: 5.04540867810293e-05"
# [1] "val_sig_mask_pvals"
# [1] 801
# [1] "val_sig_mask_ceoffs"
# [1] 991
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4252"
# [1] "val_null_thr: 1.17591721542803e-05"
# [1] "TCAx.parametric.X2Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 58"
# [1] "val_sig_thr: 0.000862068965517241"
# [1] "val_sig_mask_pvals"
# [1] 50
# [1] "val_sig_mask_ceoffs"
# [1] 57
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 37896"
# [1] "val_null_thr: 1.31940046442896e-06"
# [1] "TCAx.parametric.X2Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 890"
# [1] "val_sig_thr: 5.61797752808989e-05"
# [1] "val_sig_mask_pvals"
# [1] 720
# [1] "val_sig_mask_ceoffs"
# [1] 890
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4326"
# [1] "val_null_thr: 1.15580212667591e-05"
# [1] "TCA.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 92"
# [1] "val_sig_thr: 0.000543478260869565"
# [1] "val_sig_mask_pvals"
# [1] 51
# [1] "val_sig_mask_ceoffs"
# [1] 78
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 35413"
# [1] "val_null_thr: 1.41191088018524e-06"
# [1] "TCA.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1196"
# [1] "val_sig_thr: 4.18060200668896e-05"
# [1] "val_sig_mask_pvals"
# [1] 862
# [1] "val_sig_mask_ceoffs"
# [1] 1196
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3384"
# [1] "val_null_thr: 1.47754137115839e-05"
# [1] "TCA.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 62"
# [1] "val_sig_thr: 0.000806451612903226"
# [1] "val_sig_mask_pvals"
# [1] 51
# [1] "val_sig_mask_ceoffs"
# [1] 59
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36475"
# [1] "val_null_thr: 1.37080191912269e-06"
# [1] "TCA.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1034"
# [1] "val_sig_thr: 4.83558994197292e-05"
# [1] "val_sig_mask_pvals"
# [1] 797
# [1] "val_sig_mask_ceoffs"
# [1] 1034
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3610"
# [1] "val_null_thr: 1.38504155124654e-05"
# [1] "TCA.parametric.Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 73"
# [1] "val_sig_thr: 0.000684931506849315"
# [1] "val_sig_mask_pvals"
# [1] 50
# [1] "val_sig_mask_ceoffs"
# [1] 65
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 37057"
# [1] "val_null_thr: 1.34927274199207e-06"
# [1] "TCA.parametric.Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 995"
# [1] "val_sig_thr: 5.0251256281407e-05"
# [1] "val_sig_mask_pvals"
# [1] 769
# [1] "val_sig_mask_ceoffs"
# [1] 995
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3983"
# [1] "val_null_thr: 1.25533517449159e-05"
# [1] "TCA.parametric.XQ2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 59"
# [1] "val_sig_thr: 0.000847457627118644"
# [1] "val_sig_mask_pvals"
# [1] 49
# [1] "val_sig_mask_ceoffs"
# [1] 58
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36680"
# [1] "val_null_thr: 1.36314067611778e-06"
# [1] "TCA.parametric.XQ2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 988"
# [1] "val_sig_thr: 5.06072874493927e-05"
# [1] "val_sig_mask_pvals"
# [1] 781
# [1] "val_sig_mask_ceoffs"
# [1] 988
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3766"
# [1] "val_null_thr: 1.32766861391397e-05"
# [1] "TCA.parametric.X2Q2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 53"
# [1] "val_sig_thr: 0.000943396226415094"
# [1] "val_sig_mask_pvals"
# [1] 47
# [1] "val_sig_mask_ceoffs"
# [1] 51
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36402"
# [1] "val_null_thr: 1.37355090379649e-06"
# [1] "TCA.parametric.X2Q2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 903"
# [1] "val_sig_thr: 5.53709856035437e-05"
# [1] "val_sig_mask_pvals"
# [1] 719
# [1] "val_sig_mask_ceoffs"
# [1] 903
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3934"
# [1] "val_null_thr: 1.2709710218607e-05"
# [1] "CellDMC.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 461"
# [1] "val_sig_thr: 0.000108459869848156"
# [1] "val_sig_mask_pvals"
# [1] 62
# [1] "val_sig_mask_ceoffs"
# [1] 327
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 35538"
# [1] "val_null_thr: 1.40694467893522e-06"
# [1] "CellDMC.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1665"
# [1] "val_sig_thr: 3.003003003003e-05"
# [1] "val_sig_mask_pvals"
# [1] 945
# [1] "val_sig_mask_ceoffs"
# [1] 1665
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3447"
# [1] "val_null_thr: 1.45053669857847e-05"
# [1] "CellDMC.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 75"
# [1] "val_sig_thr: 0.000666666666666667"
# [1] "val_sig_mask_pvals"
# [1] 56
# [1] "val_sig_mask_ceoffs"
# [1] 72
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36651"
# [1] "val_null_thr: 1.36421925731904e-06"
# [1] "CellDMC.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1196"
# [1] "val_sig_thr: 4.18060200668896e-05"
# [1] "val_sig_mask_pvals"
# [1] 893
# [1] "val_sig_mask_ceoffs"
# [1] 1196
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3911"
# [1] "val_null_thr: 1.27844541038098e-05"
# [1] "Baseline.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 4819"
# [1] "val_sig_thr: 1.03755965968043e-05"
# [1] "val_sig_mask_pvals"
# [1] 3567
# [1] "val_sig_mask_ceoffs"
# [1] 4802
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 28080"
# [1] "val_null_thr: 1.78062678062678e-06"
# [1] "Baseline.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 2333"
# [1] "val_sig_thr: 2.14316330904415e-05"
# [1] "val_sig_mask_pvals"
# [1] 1617
# [1] "val_sig_mask_ceoffs"
# [1] 2283
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4345"
# [1] "val_null_thr: 1.15074798619102e-05"
# [1] "Baseline.parametric.X2.marginal"
# discovery shape:  153155 6
#
# validation shape:  144743 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 4608"
# [1] "val_sig_thr: 1.08506944444444e-05"
# [1] "val_sig_mask_pvals"
# [1] 3571
# [1] "val_sig_mask_ceoffs"
# [1] 4595
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27005"
# [1] "val_null_thr: 1.85150897981855e-06"
# [1] "Baseline.parametric.X2.joint"
# discovery shape:  153155 1
#
# validation shape:  144743 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 2077"
# [1] "val_sig_thr: 2.40731824747232e-05"
# [1] "val_sig_mask_pvals"
# [1] 1544
# [1] "val_sig_mask_ceoffs"
# [1] 2050
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4322"
# [1] "val_null_thr: 1.1568718186025e-05"
# [1] "TCAx.parametric.full.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 42"
# [1] "val_sig_thr: 0.00119047619047619"
# [1] "val_sig_mask_pvals"
# [1] 39
# [1] "val_sig_mask_ceoffs"
# [1] 41
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36061"
# [1] "val_null_thr: 1.38653947477885e-06"
# [1] "TCAx.parametric.full.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1472"
# [1] "val_sig_thr: 3.39673913043478e-05"
# [1] "val_sig_mask_pvals"
# [1] 921
# [1] "val_sig_mask_ceoffs"
# [1] 1472
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3541"
# [1] "val_null_thr: 1.4120304998588e-05"
# [1] "TCAx.parametric.X2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 42"
# [1] "val_sig_thr: 0.00119047619047619"
# [1] "val_sig_mask_pvals"
# [1] 39
# [1] "val_sig_mask_ceoffs"
# [1] 42
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36194"
# [1] "val_null_thr: 1.38144443830469e-06"
# [1] "TCAx.parametric.X2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1395"
# [1] "val_sig_thr: 3.584229390681e-05"
# [1] "val_sig_mask_pvals"
# [1] 885
# [1] "val_sig_mask_ceoffs"
# [1] 1395
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3799"
# [1] "val_null_thr: 1.31613582521716e-05"
# [1] "TCAx.parametric.Q2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 40"
# [1] "val_sig_thr: 0.00125"
# [1] "val_sig_mask_pvals"
# [1] 38
# [1] "val_sig_mask_ceoffs"
# [1] 40
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36320"
# [1] "val_null_thr: 1.37665198237885e-06"
# [1] "TCAx.parametric.Q2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1339"
# [1] "val_sig_thr: 3.73412994772218e-05"
# [1] "val_sig_mask_pvals"
# [1] 862
# [1] "val_sig_mask_ceoffs"
# [1] 1339
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3743"
# [1] "val_null_thr: 1.33582687683676e-05"
# [1] "TCAx.parametric.XQ2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 45"
# [1] "val_sig_thr: 0.00111111111111111"
# [1] "val_sig_mask_pvals"
# [1] 37
# [1] "val_sig_mask_ceoffs"
# [1] 44
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36789"
# [1] "val_null_thr: 1.35910190546087e-06"
# [1] "TCAx.parametric.XQ2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1410"
# [1] "val_sig_thr: 3.54609929078014e-05"
# [1] "val_sig_mask_pvals"
# [1] 882
# [1] "val_sig_mask_ceoffs"
# [1] 1410
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3927"
# [1] "val_null_thr: 1.27323656735421e-05"
# [1] "TCAx.parametric.X2Q2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 42"
# [1] "val_sig_thr: 0.00119047619047619"
# [1] "val_sig_mask_pvals"
# [1] 39
# [1] "val_sig_mask_ceoffs"
# [1] 42
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36345"
# [1] "val_null_thr: 1.37570504883753e-06"
# [1] "TCAx.parametric.X2Q2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1281"
# [1] "val_sig_thr: 3.9032006245121e-05"
# [1] "val_sig_mask_pvals"
# [1] 811
# [1] "val_sig_mask_ceoffs"
# [1] 1281
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3892"
# [1] "val_null_thr: 1.2846865364851e-05"
# [1] "TCA.parametric.full.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 42"
# [1] "val_sig_thr: 0.00119047619047619"
# [1] "val_sig_mask_pvals"
# [1] 37
# [1] "val_sig_mask_ceoffs"
# [1] 41
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 35351"
# [1] "val_null_thr: 1.41438714604962e-06"
# [1] "TCA.parametric.full.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1517"
# [1] "val_sig_thr: 3.295978905735e-05"
# [1] "val_sig_mask_pvals"
# [1] 954
# [1] "val_sig_mask_ceoffs"
# [1] 1517
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3336"
# [1] "val_null_thr: 1.49880095923261e-05"
# [1] "TCA.parametric.X2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 39"
# [1] "val_sig_thr: 0.00128205128205128"
# [1] "val_sig_mask_pvals"
# [1] 37
# [1] "val_sig_mask_ceoffs"
# [1] 39
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 35379"
# [1] "val_null_thr: 1.41326775770938e-06"
# [1] "TCA.parametric.X2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1460"
# [1] "val_sig_thr: 3.42465753424658e-05"
# [1] "val_sig_mask_pvals"
# [1] 922
# [1] "val_sig_mask_ceoffs"
# [1] 1460
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3403"
# [1] "val_null_thr: 1.46929180135175e-05"
# [1] "TCA.parametric.Q2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 39"
# [1] "val_sig_thr: 0.00128205128205128"
# [1] "val_sig_mask_pvals"
# [1] 37
# [1] "val_sig_mask_ceoffs"
# [1] 38
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 35659"
# [1] "val_null_thr: 1.40217056002692e-06"
# [1] "TCA.parametric.Q2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1353"
# [1] "val_sig_thr: 3.69549150036955e-05"
# [1] "val_sig_mask_pvals"
# [1] 871
# [1] "val_sig_mask_ceoffs"
# [1] 1353
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3501"
# [1] "val_null_thr: 1.42816338189089e-05"
# [1] "TCA.parametric.XQ2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 43"
# [1] "val_sig_thr: 0.00116279069767442"
# [1] "val_sig_mask_pvals"
# [1] 40
# [1] "val_sig_mask_ceoffs"
# [1] 43
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36177"
# [1] "val_null_thr: 1.38209359537828e-06"
# [1] "TCA.parametric.XQ2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1396"
# [1] "val_sig_thr: 3.58166189111748e-05"
# [1] "val_sig_mask_pvals"
# [1] 901
# [1] "val_sig_mask_ceoffs"
# [1] 1396
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3570"
# [1] "val_null_thr: 1.40056022408964e-05"
# [1] "TCA.parametric.X2Q2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 38"
# [1] "val_sig_thr: 0.00131578947368421"
# [1] "val_sig_mask_pvals"
# [1] 36
# [1] "val_sig_mask_ceoffs"
# [1] 38
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36290"
# [1] "val_null_thr: 1.37779002480022e-06"
# [1] "TCA.parametric.X2Q2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1294"
# [1] "val_sig_thr: 3.86398763523957e-05"
# [1] "val_sig_mask_pvals"
# [1] 820
# [1] "val_sig_mask_ceoffs"
# [1] 1294
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3511"
# [1] "val_null_thr: 1.42409569923099e-05"
# [1] "CellDMC.parametric.full.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 41"
# [1] "val_sig_thr: 0.00121951219512195"
# [1] "val_sig_mask_pvals"
# [1] 40
# [1] "val_sig_mask_ceoffs"
# [1] 40
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 35394"
# [1] "val_null_thr: 1.41266881392326e-06"
# [1] "CellDMC.parametric.full.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1543"
# [1] "val_sig_thr: 3.24044069993519e-05"
# [1] "val_sig_mask_pvals"
# [1] 1028
# [1] "val_sig_mask_ceoffs"
# [1] 1543
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3412"
# [1] "val_null_thr: 1.46541617819461e-05"
# [1] "CellDMC.parametric.X2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 46"
# [1] "val_sig_thr: 0.00108695652173913"
# [1] "val_sig_mask_pvals"
# [1] 43
# [1] "val_sig_mask_ceoffs"
# [1] 45
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 36345"
# [1] "val_null_thr: 1.37570504883753e-06"
# [1] "CellDMC.parametric.X2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 1493"
# [1] "val_sig_thr: 3.34896182183523e-05"
# [1] "val_sig_mask_pvals"
# [1] 981
# [1] "val_sig_mask_ceoffs"
# [1] 1493
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 3711"
# [1] "val_null_thr: 1.34734572891404e-05"
# [1] "Baseline.parametric.full.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 6613"
# [1] "val_sig_thr: 7.56086496295176e-06"
# [1] "val_sig_mask_pvals"
# [1] 3925
# [1] "val_sig_mask_ceoffs"
# [1] 6592
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 28850"
# [1] "val_null_thr: 1.73310225303293e-06"
# [1] "Baseline.parametric.full.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 2813"
# [1] "val_sig_thr: 1.77746178457163e-05"
# [1] "val_sig_mask_pvals"
# [1] 1747
# [1] "val_sig_mask_ceoffs"
# [1] 2801
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4207"
# [1] "val_null_thr: 1.18849536486808e-05"
# [1] "Baseline.parametric.X2.marginal"
# discovery shape:  144743 6
#
# validation shape:  153155 6
#
# after
#
# discovery shape:  129338 6
#
# validation shape:  129338 6
#
# ###################
# [1] "dis_sig_thr: 6.4430664872917e-08"
# [1] "n_ds: 7149"
# [1] "val_sig_thr: 6.99398517275143e-06"
# [1] "val_sig_mask_pvals"
# [1] 4098
# [1] "val_sig_mask_ceoffs"
# [1] 7134
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 28527"
# [1] "val_null_thr: 1.75272548813405e-06"
# [1] "Baseline.parametric.X2.joint"
# discovery shape:  144743 1
#
# validation shape:  153155 1
#
# after
#
# discovery shape:  129338 1
#
# validation shape:  129338 1
#
# ###################
# [1] "dis_sig_thr: 3.86583989237502e-07"
# [1] "n_ds: 2714"
# [1] "val_sig_thr: 1.84229918938836e-05"
# [1] "val_sig_mask_pvals"
# [1] 1753
# [1] "val_sig_mask_ceoffs"
# [1] 2704
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4146"
# [1] "val_null_thr: 1.20598166907863e-05"
# [1] "liu.hannon1"
# [1] "TCAx.parametric.full.marginal"
# discovery shape:  153155 6
#
# validation shape:  134250 6
#
# after
#
# discovery shape:  120763 6
#
# validation shape:  120763 6
#
# ###################
# [1] "dis_sig_thr: 6.90056833080773e-08"
# [1] "n_ds: 69"
# [1] "val_sig_thr: 0.00072463768115942"
# [1] "val_sig_mask_pvals"
# [1] 52
# [1] "val_sig_mask_ceoffs"
# [1] 65
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 35395"
# [1] "val_null_thr: 1.41262890238734e-06"
# [1] "TCAx.parametric.full.joint"
# discovery shape:  153155 1
#
# validation shape:  134250 1
#
# after
#
# discovery shape:  120763 1
#
# validation shape:  120763 1
#
# ###################
# [1] "dis_sig_thr: 4.14034099848464e-07"
# [1] "n_ds: 1065"
# [1] "val_sig_thr: 4.69483568075117e-05"
# [1] "val_sig_mask_pvals"
# [1] 555
# [1] "val_sig_mask_ceoffs"
# [1] 1065
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 4101"
# [1] "val_null_thr: 1.21921482565228e-05"
# [1] "TCAx.parametric.X2.marginal"
# ...
# [1] "val_sig_mask_pvals"
# [1] 3163
# [1] "val_sig_mask_ceoffs"
# [1] 3163
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2013"
# [1] "val_null_thr: 2.48385494287134e-05"
# [1] "TCA.parametric.X2Q2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 32"
# [1] "val_sig_thr: 0.0015625"
# [1] "val_sig_mask_pvals"
# [1] 32
# [1] "val_sig_mask_ceoffs"
# [1] 32
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27357"
# [1] "val_null_thr: 1.82768578425997e-06"
# [1] "TCA.parametric.X2Q2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 2825"
# [1] "val_sig_thr: 1.76991150442478e-05"
# [1] "val_sig_mask_pvals"
# [1] 2825
# [1] "val_sig_mask_ceoffs"
# [1] 2825
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1990"
# [1] "val_null_thr: 2.51256281407035e-05"
# [1] "CellDMC.parametric.full.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 40"
# [1] "val_sig_thr: 0.00125"
# [1] "val_sig_mask_pvals"
# [1] 40
# [1] "val_sig_mask_ceoffs"
# [1] 40
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 26880"
# [1] "val_null_thr: 1.86011904761905e-06"
# [1] "CellDMC.parametric.full.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 4453"
# [1] "val_sig_thr: 1.12283853581855e-05"
# [1] "val_sig_mask_pvals"
# [1] 4453
# [1] "val_sig_mask_ceoffs"
# [1] 4453
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1819"
# [1] "val_null_thr: 2.74876305662452e-05"
# [1] "CellDMC.parametric.X2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 40"
# [1] "val_sig_thr: 0.00125"
# [1] "val_sig_mask_pvals"
# [1] 40
# [1] "val_sig_mask_ceoffs"
# [1] 40
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27455"
# [1] "val_null_thr: 1.82116190129303e-06"
# [1] "CellDMC.parametric.X2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3544"
# [1] "val_sig_thr: 1.41083521444695e-05"
# [1] "val_sig_mask_pvals"
# [1] 3544
# [1] "val_sig_mask_ceoffs"
# [1] 3544
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2044"
# [1] "val_null_thr: 2.44618395303327e-05"
# [1] "Baseline.parametric.full.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 18159"
# [1] "val_sig_thr: 2.75345558676139e-06"
# [1] "val_sig_mask_pvals"
# [1] 18159
# [1] "val_sig_mask_ceoffs"
# [1] 18159
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 13214"
# [1] "val_null_thr: 3.78386559709399e-06"
# [1] "Baseline.parametric.full.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 7153"
# [1] "val_sig_thr: 6.9900740947854e-06"
# [1] "val_sig_mask_pvals"
# [1] 7153
# [1] "val_sig_mask_ceoffs"
# [1] 7153
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1872"
# [1] "val_null_thr: 2.67094017094017e-05"
# [1] "Baseline.parametric.X2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 20281"
# [1] "val_sig_thr: 2.46536166855678e-06"
# [1] "val_sig_mask_pvals"
# [1] 20281
# [1] "val_sig_mask_ceoffs"
# [1] 20281
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 12812"
# [1] "val_null_thr: 3.9025913206369e-06"
# [1] "Baseline.parametric.X2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 5907"
# [1] "val_sig_thr: 8.46453360419841e-06"
# [1] "val_sig_mask_pvals"
# [1] 5907
# [1] "val_sig_mask_ceoffs"
# [1] 5907
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1923"
# [1] "val_null_thr: 2.60010400416017e-05"
# [1] "TCAx.parametric.full.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 39"
# [1] "val_sig_thr: 0.00128205128205128"
# [1] "val_sig_mask_pvals"
# [1] 39
# [1] "val_sig_mask_ceoffs"
# [1] 39
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27333"
# [1] "val_null_thr: 1.82929060110489e-06"
# [1] "TCAx.parametric.full.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3866"
# [1] "val_sig_thr: 1.29332643559234e-05"
# [1] "val_sig_mask_pvals"
# [1] 3866
# [1] "val_sig_mask_ceoffs"
# [1] 3866
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2049"
# [1] "val_null_thr: 2.44021473889702e-05"
# [1] "TCAx.parametric.X2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 39"
# [1] "val_sig_thr: 0.00128205128205128"
# [1] "val_sig_mask_pvals"
# [1] 39
# [1] "val_sig_mask_ceoffs"
# [1] 39
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27880"
# [1] "val_null_thr: 1.79340028694405e-06"
# [1] "TCAx.parametric.X2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3076"
# [1] "val_sig_thr: 1.62548764629389e-05"
# [1] "val_sig_mask_pvals"
# [1] 3076
# [1] "val_sig_mask_ceoffs"
# [1] 3076
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2216"
# [1] "val_null_thr: 2.25631768953069e-05"
# [1] "TCAx.parametric.Q2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 35"
# [1] "val_sig_thr: 0.00142857142857143"
# [1] "val_sig_mask_pvals"
# [1] 35
# [1] "val_sig_mask_ceoffs"
# [1] 35
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 26872"
# [1] "val_null_thr: 1.86067281929146e-06"
# [1] "TCAx.parametric.Q2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3606"
# [1] "val_sig_thr: 1.38657792567942e-05"
# [1] "val_sig_mask_pvals"
# [1] 3606
# [1] "val_sig_mask_ceoffs"
# [1] 3606
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2006"
# [1] "val_null_thr: 2.49252243270189e-05"
# [1] "TCAx.parametric.XQ2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 35"
# [1] "val_sig_thr: 0.00142857142857143"
# [1] "val_sig_mask_pvals"
# [1] 35
# [1] "val_sig_mask_ceoffs"
# [1] 35
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27510"
# [1] "val_null_thr: 1.81752090149037e-06"
# [1] "TCAx.parametric.XQ2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3149"
# [1] "val_sig_thr: 1.58780565258812e-05"
# [1] "val_sig_mask_pvals"
# [1] 3149
# [1] "val_sig_mask_ceoffs"
# [1] 3149
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2165"
# [1] "val_null_thr: 2.3094688221709e-05"
# [1] "TCAx.parametric.X2Q2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 34"
# [1] "val_sig_thr: 0.00147058823529412"
# [1] "val_sig_mask_pvals"
# [1] 34
# [1] "val_sig_mask_ceoffs"
# [1] 34
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27614"
# [1] "val_null_thr: 1.81067574418773e-06"
# [1] "TCAx.parametric.X2Q2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 2848"
# [1] "val_sig_thr: 1.75561797752809e-05"
# [1] "val_sig_mask_pvals"
# [1] 2848
# [1] "val_sig_mask_ceoffs"
# [1] 2848
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2150"
# [1] "val_null_thr: 2.32558139534884e-05"
# [1] "TCA.parametric.full.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 38"
# [1] "val_sig_thr: 0.00131578947368421"
# [1] "val_sig_mask_pvals"
# [1] 38
# [1] "val_sig_mask_ceoffs"
# [1] 38
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 26830"
# [1] "val_null_thr: 1.86358553857622e-06"
# [1] "TCA.parametric.full.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3949"
# [1] "val_sig_thr: 1.26614332742466e-05"
# [1] "val_sig_mask_pvals"
# [1] 3949
# [1] "val_sig_mask_ceoffs"
# [1] 3949
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1787"
# [1] "val_null_thr: 2.79798545047566e-05"
# [1] "TCA.parametric.X2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 38"
# [1] "val_sig_thr: 0.00131578947368421"
# [1] "val_sig_mask_pvals"
# [1] 38
# [1] "val_sig_mask_ceoffs"
# [1] 38
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27061"
# [1] "val_null_thr: 1.84767746942094e-06"
# [1] "TCA.parametric.X2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3153"
# [1] "val_sig_thr: 1.58579130986362e-05"
# [1] "val_sig_mask_pvals"
# [1] 3153
# [1] "val_sig_mask_ceoffs"
# [1] 3153
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2042"
# [1] "val_null_thr: 2.44857982370225e-05"
# [1] "TCA.parametric.Q2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 38"
# [1] "val_sig_thr: 0.00131578947368421"
# [1] "val_sig_mask_pvals"
# [1] 38
# [1] "val_sig_mask_ceoffs"
# [1] 38
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27109"
# [1] "val_null_thr: 1.84440591685418e-06"
# [1] "TCA.parametric.Q2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3611"
# [1] "val_sig_thr: 1.3846579894766e-05"
# [1] "val_sig_mask_pvals"
# [1] 3611
# [1] "val_sig_mask_ceoffs"
# [1] 3611
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1927"
# [1] "val_null_thr: 2.59470679813181e-05"
# [1] "TCA.parametric.XQ2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 42"
# [1] "val_sig_thr: 0.00119047619047619"
# [1] "val_sig_mask_pvals"
# [1] 42
# [1] "val_sig_mask_ceoffs"
# [1] 42
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27646"
# [1] "val_null_thr: 1.80857990306012e-06"
# [1] "TCA.parametric.XQ2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3163"
# [1] "val_sig_thr: 1.58077774264938e-05"
# [1] "val_sig_mask_pvals"
# [1] 3163
# [1] "val_sig_mask_ceoffs"
# [1] 3163
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2013"
# [1] "val_null_thr: 2.48385494287134e-05"
# [1] "TCA.parametric.X2Q2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 32"
# [1] "val_sig_thr: 0.0015625"
# [1] "val_sig_mask_pvals"
# [1] 32
# [1] "val_sig_mask_ceoffs"
# [1] 32
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27357"
# [1] "val_null_thr: 1.82768578425997e-06"
# [1] "TCA.parametric.X2Q2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 2825"
# [1] "val_sig_thr: 1.76991150442478e-05"
# [1] "val_sig_mask_pvals"
# [1] 2825
# [1] "val_sig_mask_ceoffs"
# [1] 2825
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1990"
# [1] "val_null_thr: 2.51256281407035e-05"
# [1] "CellDMC.parametric.full.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 40"
# [1] "val_sig_thr: 0.00125"
# [1] "val_sig_mask_pvals"
# [1] 40
# [1] "val_sig_mask_ceoffs"
# [1] 40
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 26880"
# [1] "val_null_thr: 1.86011904761905e-06"
# [1] "CellDMC.parametric.full.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 4453"
# [1] "val_sig_thr: 1.12283853581855e-05"
# [1] "val_sig_mask_pvals"
# [1] 4453
# [1] "val_sig_mask_ceoffs"
# [1] 4453
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1819"
# [1] "val_null_thr: 2.74876305662452e-05"
# [1] "CellDMC.parametric.X2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 40"
# [1] "val_sig_thr: 0.00125"
# [1] "val_sig_mask_pvals"
# [1] 40
# [1] "val_sig_mask_ceoffs"
# [1] 40
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 27455"
# [1] "val_null_thr: 1.82116190129303e-06"
# [1] "CellDMC.parametric.X2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 3544"
# [1] "val_sig_thr: 1.41083521444695e-05"
# [1] "val_sig_mask_pvals"
# [1] 3544
# [1] "val_sig_mask_ceoffs"
# [1] 3544
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 2044"
# [1] "val_null_thr: 2.44618395303327e-05"
# [1] "Baseline.parametric.full.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 18159"
# [1] "val_sig_thr: 2.75345558676139e-06"
# [1] "val_sig_mask_pvals"
# [1] 18159
# [1] "val_sig_mask_ceoffs"
# [1] 18159
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 13214"
# [1] "val_null_thr: 3.78386559709399e-06"
# [1] "Baseline.parametric.full.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 7153"
# [1] "val_sig_thr: 6.9900740947854e-06"
# [1] "val_sig_mask_pvals"
# [1] 7153
# [1] "val_sig_mask_ceoffs"
# [1] 7153
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1872"
# [1] "val_null_thr: 2.67094017094017e-05"
# [1] "Baseline.parametric.X2.marginal"
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# after
#
# discovery shape:  95360 6
#
# validation shape:  95360 6
#
# ###################
# [1] "dis_sig_thr: 8.73881431767338e-08"
# [1] "n_ds: 20281"
# [1] "val_sig_thr: 2.46536166855678e-06"
# [1] "val_sig_mask_pvals"
# [1] 20281
# [1] "val_sig_mask_ceoffs"
# [1] 20281
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 12812"
# [1] "val_null_thr: 3.9025913206369e-06"
# [1] "Baseline.parametric.X2.joint"
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# after
#
# discovery shape:  95360 1
#
# validation shape:  95360 1
#
# ###################
# [1] "dis_sig_thr: 5.24328859060403e-07"
# [1] "n_ds: 5907"
# [1] "val_sig_thr: 8.46453360419841e-06"
# [1] "val_sig_mask_pvals"
# [1] 5907
# [1] "val_sig_mask_ceoffs"
# [1] 5907
# [1] "dis_null_thr: 0.95"
# [1] "n_dn: 1923"
# [1] "val_null_thr: 2.60010400416017e-05"

# %%
#biggest sample
bidir_confusion_dfs_list$'liu.liu'
# Out:
# $forward
#                                     TP FN FP    TN recall precision F1
# TCAx.parametric.full.marginal       80  0  0 44734      1         1  1
# TCAx.parametric.full.joint        1098  0  0  5346      1         1  1
# TCAx.parametric.X2.marginal         62  0  0 44247      1         1  1
# TCAx.parametric.X2.joint           992  0  0  5400      1         1  1
# TCAx.parametric.Q2.marginal         61  0  0 45150      1         1  1
# TCAx.parametric.Q2.joint           953  0  0  5709      1         1  1
# TCAx.parametric.XQ2.marginal        60  0  0 44470      1         1  1
# TCAx.parametric.XQ2.joint          980  0  0  5383      1         1  1
# TCAx.parametric.X2Q2.marginal       60  0  0 45059      1         1  1
# TCAx.parametric.X2Q2.joint         876  0  0  5450      1         1  1
# TCA.parametric.full.marginal       108  0  0 42271      1         1  1
# TCA.parametric.full.joint         1200  0  0  4394      1         1  1
# TCA.parametric.X2.marginal          65  0  0 43259      1         1  1
# TCA.parametric.X2.joint           1022  0  0  4660      1         1  1
# TCA.parametric.Q2.marginal          83  0  0 43897      1         1  1
# TCA.parametric.Q2.joint            989  0  0  5000      1         1  1
# TCA.parametric.XQ2.marginal         63  0  0 43624      1         1  1
# TCA.parametric.XQ2.joint           972  0  0  4743      1         1  1
# TCA.parametric.X2Q2.marginal        55  0  0 43370      1         1  1
# TCA.parametric.X2Q2.joint          887  0  0  4966      1         1  1
# CellDMC.parametric.full.marginal   607  0  0 42276      1         1  1
# CellDMC.parametric.full.joint     1730  0  0  4461      1         1  1
# CellDMC.parametric.X2.marginal      78  0  0 43821      1         1  1
# CellDMC.parametric.X2.joint       1171  0  0  5015      1         1  1
# Baseline.parametric.full.marginal 4757  0  0 34188      1         1  1
# Baseline.parametric.full.joint    2288  0  0  5422      1         1  1
# Baseline.parametric.X2.marginal   4546  0  0 32683      1         1  1
# Baseline.parametric.X2.joint      2031  0  0  5479      1         1  1
#                                   specificity accuracy MCC
# TCAx.parametric.full.marginal               1        1   1
# TCAx.parametric.full.joint                  1        1   1
# TCAx.parametric.X2.marginal                 1        1   1
# TCAx.parametric.X2.joint                    1        1   1
# TCAx.parametric.Q2.marginal                 1        1   1
# TCAx.parametric.Q2.joint                    1        1   1
# TCAx.parametric.XQ2.marginal                1        1   1
# TCAx.parametric.XQ2.joint                   1        1   1
# TCAx.parametric.X2Q2.marginal               1        1   1
# TCAx.parametric.X2Q2.joint                  1        1   1
# TCA.parametric.full.marginal                1        1   1
# TCA.parametric.full.joint                   1        1   1
# TCA.parametric.X2.marginal                  1        1   1
# TCA.parametric.X2.joint                     1        1   1
# TCA.parametric.Q2.marginal                  1        1   1
# TCA.parametric.Q2.joint                     1        1   1
# TCA.parametric.XQ2.marginal                 1        1   1
# TCA.parametric.XQ2.joint                    1        1   1
# TCA.parametric.X2Q2.marginal                1        1   1
# TCA.parametric.X2Q2.joint                   1        1   1
# CellDMC.parametric.full.marginal            1        1   1
# CellDMC.parametric.full.joint               1        1   1
# CellDMC.parametric.X2.marginal              1        1   1
# CellDMC.parametric.X2.joint                 1        1   1
# Baseline.parametric.full.marginal           1        1   1
# Baseline.parametric.full.joint              1        1   1
# Baseline.parametric.X2.marginal             1        1   1
# Baseline.parametric.X2.joint                1        1   1
#
# $backward
#                                     TP FN FP    TN recall precision F1
# TCAx.parametric.full.marginal       80  0  0 44734      1         1  1
# TCAx.parametric.full.joint        1098  0  0  5346      1         1  1
# TCAx.parametric.X2.marginal         62  0  0 44247      1         1  1
# TCAx.parametric.X2.joint           992  0  0  5400      1         1  1
# TCAx.parametric.Q2.marginal         61  0  0 45150      1         1  1
# TCAx.parametric.Q2.joint           953  0  0  5709      1         1  1
# TCAx.parametric.XQ2.marginal        60  0  0 44470      1         1  1
# TCAx.parametric.XQ2.joint          980  0  0  5383      1         1  1
# TCAx.parametric.X2Q2.marginal       60  0  0 45059      1         1  1
# TCAx.parametric.X2Q2.joint         876  0  0  5450      1         1  1
# TCA.parametric.full.marginal       108  0  0 42271      1         1  1
# TCA.parametric.full.joint         1200  0  0  4394      1         1  1
# TCA.parametric.X2.marginal          65  0  0 43259      1         1  1
# TCA.parametric.X2.joint           1022  0  0  4660      1         1  1
# TCA.parametric.Q2.marginal          83  0  0 43897      1         1  1
# TCA.parametric.Q2.joint            989  0  0  5000      1         1  1
# TCA.parametric.XQ2.marginal         63  0  0 43624      1         1  1
# TCA.parametric.XQ2.joint           972  0  0  4743      1         1  1
# TCA.parametric.X2Q2.marginal        55  0  0 43370      1         1  1
# TCA.parametric.X2Q2.joint          887  0  0  4966      1         1  1
# CellDMC.parametric.full.marginal   607  0  0 42276      1         1  1
# CellDMC.parametric.full.joint     1730  0  0  4461      1         1  1
# CellDMC.parametric.X2.marginal      78  0  0 43821      1         1  1
# CellDMC.parametric.X2.joint       1171  0  0  5015      1         1  1
# Baseline.parametric.full.marginal 4757  0  0 34188      1         1  1
# Baseline.parametric.full.joint    2288  0  0  5422      1         1  1
# Baseline.parametric.X2.marginal   4546  0  0 32683      1         1  1
# Baseline.parametric.X2.joint      2031  0  0  5479      1         1  1
#                                   specificity accuracy MCC
# TCAx.parametric.full.marginal               1        1   1
# TCAx.parametric.full.joint                  1        1   1
# TCAx.parametric.X2.marginal                 1        1   1
# TCAx.parametric.X2.joint                    1        1   1
# TCAx.parametric.Q2.marginal                 1        1   1
# TCAx.parametric.Q2.joint                    1        1   1
# TCAx.parametric.XQ2.marginal                1        1   1
# TCAx.parametric.XQ2.joint                   1        1   1
# TCAx.parametric.X2Q2.marginal               1        1   1
# TCAx.parametric.X2Q2.joint                  1        1   1
# TCA.parametric.full.marginal                1        1   1
# TCA.parametric.full.joint                   1        1   1
# TCA.parametric.X2.marginal                  1        1   1
# TCA.parametric.X2.joint                     1        1   1
# TCA.parametric.Q2.marginal                  1        1   1
# TCA.parametric.Q2.joint                     1        1   1
# TCA.parametric.XQ2.marginal                 1        1   1
# TCA.parametric.XQ2.joint                    1        1   1
# TCA.parametric.X2Q2.marginal                1        1   1
# TCA.parametric.X2Q2.joint                   1        1   1
# CellDMC.parametric.full.marginal            1        1   1
# CellDMC.parametric.full.joint               1        1   1
# CellDMC.parametric.X2.marginal              1        1   1
# CellDMC.parametric.X2.joint                 1        1   1
# Baseline.parametric.full.marginal           1        1   1
# Baseline.parametric.full.joint              1        1   1
# Baseline.parametric.X2.marginal             1        1   1
# Baseline.parametric.X2.joint                1        1   1

# %%
#smallest sample
bidir_confusion_dfs_list$'hannum.hannum'$forward
# Out:
#                                   TP   FN FP TN    recall precision F1
# TCAx.parametric.full.marginal       47 0  0  40256 1      1         1
# TCAx.parametric.full.joint        1564 0  0   3949 1      1         1
# TCAx.parametric.X2.marginal         43 0  0  40576 1      1         1
# TCAx.parametric.X2.joint          1486 0  0   4236 1      1         1
# TCAx.parametric.Q2.marginal         46 0  0  40452 1      1         1
# TCAx.parametric.Q2.joint          1419 0  0   4163 1      1         1
# TCAx.parametric.XQ2.marginal        49 0  0  41152 1      1         1
# TCAx.parametric.XQ2.joint         1490 0  0   4341 1      1         1
# TCAx.parametric.X2Q2.marginal       45 0  0  40719 1      1         1
# TCAx.parametric.X2Q2.joint        1355 0  0   4343 1      1         1
# TCA.parametric.full.marginal        46 0  0  39583 1      1         1
# TCA.parametric.full.joint         1603 0  0   3785 1      1         1
# TCA.parametric.X2.marginal          44 0  0  39771 1      1         1
# TCA.parametric.X2.joint           1550 0  0   3811 1      1         1
# TCA.parametric.Q2.marginal          42 0  0  39992 1      1         1
# TCA.parametric.Q2.joint           1430 0  0   3971 1      1         1
# TCA.parametric.XQ2.marginal         48 0  0  40573 1      1         1
# TCA.parametric.XQ2.joint          1476 0  0   3990 1      1         1
# TCA.parametric.X2Q2.marginal        41 0  0  40522 1      1         1
# TCA.parametric.X2Q2.joint         1365 0  0   3903 1      1         1
# CellDMC.parametric.full.marginal    46 0  0  39546 1      1         1
# CellDMC.parametric.full.joint     1648 0  0   3825 1      1         1
# CellDMC.parametric.X2.marginal      48 0  0  40765 1      1         1
# CellDMC.parametric.X2.joint       1589 0  0   4172 1      1         1
# Baseline.parametric.full.marginal 6907 0  0  32493 1      1         1
# Baseline.parametric.full.joint    2989 0  0   4745 1      1         1
# Baseline.parametric.X2.marginal   7464 0  0  32176 1      1         1
# Baseline.parametric.X2.joint      2886 0  0   4661 1      1         1
#                                   specificity accuracy MCC
# TCAx.parametric.full.marginal     1           1        1
# TCAx.parametric.full.joint        1           1        1
# TCAx.parametric.X2.marginal       1           1        1
# TCAx.parametric.X2.joint          1           1        1
# TCAx.parametric.Q2.marginal       1           1        1
# TCAx.parametric.Q2.joint          1           1        1
# TCAx.parametric.XQ2.marginal      1           1        1
# TCAx.parametric.XQ2.joint         1           1        1
# TCAx.parametric.X2Q2.marginal     1           1        1
# TCAx.parametric.X2Q2.joint        1           1        1
# TCA.parametric.full.marginal      1           1        1
# TCA.parametric.full.joint         1           1        1
# TCA.parametric.X2.marginal        1           1        1
# TCA.parametric.X2.joint           1           1        1
# TCA.parametric.Q2.marginal        1           1        1
# TCA.parametric.Q2.joint           1           1        1
# TCA.parametric.XQ2.marginal       1           1        1
# TCA.parametric.XQ2.joint          1           1        1
# TCA.parametric.X2Q2.marginal      1           1        1
# TCA.parametric.X2Q2.joint         1           1        1
# CellDMC.parametric.full.marginal  1           1        1
# CellDMC.parametric.full.joint     1           1        1
# CellDMC.parametric.X2.marginal    1           1        1
# CellDMC.parametric.X2.joint       1           1        1
# Baseline.parametric.full.marginal 1           1        1
# Baseline.parametric.full.joint    1           1        1
# Baseline.parametric.X2.marginal   1           1        1
# Baseline.parametric.X2.joint      1           1        1

# %%
bidir_confusion_dfs_list$'liu.hannum'
# Out:
# $forward
#                                     TP   FN FP    TN    recall precision
# TCAx.parametric.full.marginal       55   17  1 37754 0.7638889 0.9821429
# TCAx.parametric.full.joint         837  267  2  4265 0.7581522 0.9976162
# TCAx.parametric.X2.marginal         52    8  0 37248 0.8666667 1.0000000
# TCAx.parametric.X2.joint           790  220  3  4239 0.7821782 0.9962169
# TCAx.parametric.Q2.marginal         49    7  0 38031 0.8750000 1.0000000
# TCAx.parametric.Q2.joint           755  207  3  4565 0.7848233 0.9960422
# TCAx.parametric.XQ2.marginal        51    8  1 37447 0.8644068 0.9807692
# TCAx.parametric.XQ2.joint          801  190  3  4249 0.8082745 0.9962687
# TCAx.parametric.X2Q2.marginal       50    8  2 37894 0.8620690 0.9615385
# TCAx.parametric.X2Q2.joint         720  170  5  4321 0.8089888 0.9931034
# TCA.parametric.full.marginal        51   41  3 35410 0.5543478 0.9444444
# TCA.parametric.full.joint          862  334  3  3381 0.7207358 0.9965318
# TCA.parametric.X2.marginal          51   11  0 36475 0.8225806 1.0000000
# TCA.parametric.X2.joint            797  237  4  3606 0.7707930 0.9950062
# TCA.parametric.Q2.marginal          50   23  0 37057 0.6849315 1.0000000
# TCA.parametric.Q2.joint            769  226  3  3980 0.7728643 0.9961140
# TCA.parametric.XQ2.marginal         49   10  0 36680 0.8305085 1.0000000
# TCA.parametric.XQ2.joint           781  207  3  3763 0.7904858 0.9961735
# TCA.parametric.X2Q2.marginal        47    6  0 36402 0.8867925 1.0000000
# TCA.parametric.X2Q2.joint          719  184  2  3932 0.7962348 0.9972261
# CellDMC.parametric.full.marginal    61  400  0 35538 0.1323210 1.0000000
# CellDMC.parametric.full.joint      945  720  3  3444 0.5675676 0.9968354
# CellDMC.parametric.X2.marginal      56   19  0 36651 0.7466667 1.0000000
# CellDMC.parametric.X2.joint        893  303  1  3910 0.7466555 0.9988814
# Baseline.parametric.full.marginal 3567 1252 16 28064 0.7401951 0.9955345
# Baseline.parametric.full.joint    1617  716  9  4336 0.6930990 0.9944649
# Baseline.parametric.X2.marginal   3571 1037  9 26996 0.7749566 0.9974860
# Baseline.parametric.X2.joint      1544  533 10  4312 0.7433799 0.9935650
#                                          F1 specificity  accuracy       MCC
# TCAx.parametric.full.marginal     0.8593750   0.9999735 0.9995241 0.8659551
# TCAx.parametric.full.joint        0.8615543   0.9995313 0.9499162 0.8433498
# TCAx.parametric.X2.marginal       0.9285714   1.0000000 0.9997856 0.9308494
# TCAx.parametric.X2.joint          0.8763172   0.9992928 0.9575400 0.8602082
# TCAx.parametric.Q2.marginal       0.9333333   1.0000000 0.9998162 0.9353283
# TCAx.parametric.Q2.joint          0.8779070   0.9993433 0.9620253 0.8643190
# TCAx.parametric.XQ2.marginal      0.9189189   0.9999733 0.9997600 0.9206371
# TCAx.parametric.XQ2.joint         0.8924791   0.9992944 0.9631890 0.8774906
# TCAx.parametric.X2Q2.marginal     0.9090909   0.9999472 0.9997365 0.9103185
# TCAx.parametric.X2Q2.joint        0.8916409   0.9988442 0.9664494 0.8784546
# TCA.parametric.full.marginal      0.6986301   0.9999153 0.9987607 0.7230696
# TCA.parametric.full.joint         0.8364871   0.9991135 0.9264192 0.8078577
# TCA.parametric.X2.marginal        0.9026549   1.0000000 0.9996989 0.9068256
# TCA.parametric.X2.joint           0.8686649   0.9988920 0.9481051 0.8475697
# TCA.parametric.Q2.marginal        0.8130081   1.0000000 0.9993806 0.8273492
# TCA.parametric.Q2.joint           0.8704018   0.9992468 0.9539976 0.8530082
# TCA.parametric.XQ2.marginal       0.9074074   1.0000000 0.9997278 0.9111982
# TCA.parametric.XQ2.joint          0.8814898   0.9992034 0.9558267 0.8634189
# TCA.parametric.X2Q2.marginal      0.9400000   1.0000000 0.9998354 0.9416190
# TCA.parametric.X2Q2.joint         0.8854680   0.9994916 0.9615464 0.8706017
# CellDMC.parametric.full.marginal  0.2337165   1.0000000 0.9888886 0.3617296
# CellDMC.parametric.full.joint     0.7233065   0.9991297 0.8585681 0.6833124
# CellDMC.parametric.X2.marginal    0.8549618   1.0000000 0.9994827 0.8638749
# CellDMC.parametric.X2.joint       0.8545455   0.9997443 0.9404739 0.8317954
# Baseline.parametric.full.marginal 0.8490836   0.9994302 0.9614578 0.8394851
# Baseline.parametric.full.joint    0.8168729   0.9979287 0.8914346 0.7676367
# Baseline.parametric.X2.marginal   0.8722521   0.9996667 0.9669123 0.8625665
# Baseline.parametric.X2.joint      0.8504544   0.9976863 0.9151430 0.8091801
#
# $backward
#                                     TP   FN FP    TN    recall precision
# TCAx.parametric.full.marginal       39    3  1 36060 0.9285714 0.9750000
# TCAx.parametric.full.joint         921  551  5  3536 0.6256793 0.9946004
# TCAx.parametric.X2.marginal         39    3  0 36194 0.9285714 1.0000000
# TCAx.parametric.X2.joint           885  510  6  3793 0.6344086 0.9932660
# TCAx.parametric.Q2.marginal         38    2  0 36320 0.9500000 1.0000000
# TCAx.parametric.Q2.joint           862  477  1  3742 0.6437640 0.9988413
# TCAx.parametric.XQ2.marginal        37    8  0 36789 0.8222222 1.0000000
# TCAx.parametric.XQ2.joint          882  528  2  3925 0.6255319 0.9977376
# TCAx.parametric.X2Q2.marginal       39    3  0 36345 0.9285714 1.0000000
# TCAx.parametric.X2Q2.joint         811  470  3  3889 0.6330991 0.9963145
# TCA.parametric.full.marginal        37    5  3 35348 0.8809524 0.9250000
# TCA.parametric.full.joint          954  563  6  3330 0.6288728 0.9937500
# TCA.parametric.X2.marginal          37    2  0 35379 0.9487179 1.0000000
# TCA.parametric.X2.joint            922  538  7  3396 0.6315068 0.9924650
# TCA.parametric.Q2.marginal          37    2  3 35656 0.9487179 0.9250000
# TCA.parametric.Q2.joint            871  482  2  3499 0.6437546 0.9977090
# TCA.parametric.XQ2.marginal         40    3  0 36177 0.9302326 1.0000000
# TCA.parametric.XQ2.joint           901  495  1  3569 0.6454155 0.9988914
# TCA.parametric.X2Q2.marginal        36    2  1 36289 0.9473684 0.9729730
# TCA.parametric.X2Q2.joint          820  474  2  3509 0.6336940 0.9975669
# CellDMC.parametric.full.marginal    39    2 21 35373 0.9512195 0.6500000
# CellDMC.parametric.full.joint     1028  515 12  3400 0.6662346 0.9884615
# CellDMC.parametric.X2.marginal      43    3  0 36345 0.9347826 1.0000000
# CellDMC.parametric.X2.joint        981  512  6  3705 0.6570663 0.9939210
# Baseline.parametric.full.marginal 3925 2688 21 28829 0.5935279 0.9946782
# Baseline.parametric.full.joint    1747 1066 21  4186 0.6210451 0.9881222
# Baseline.parametric.X2.marginal   4098 3051 13 28514 0.5732270 0.9968378
# Baseline.parametric.X2.joint      1753  961 19  4127 0.6459101 0.9892777
#                                          F1 specificity  accuracy       MCC
# TCAx.parametric.full.marginal     0.9512195   0.9999723 0.9998892 0.9514478
# TCAx.parametric.full.joint        0.7681401   0.9985880 0.8890884 0.7326215
# TCAx.parametric.X2.marginal       0.9629630   1.0000000 0.9999172 0.9635842
# TCAx.parametric.X2.joint          0.7742782   0.9984206 0.9006546 0.7440185
# TCAx.parametric.Q2.marginal       0.9743590   1.0000000 0.9999450 0.9746526
# TCAx.parametric.Q2.joint          0.7829246   0.9997328 0.9059425 0.7549818
# TCAx.parametric.XQ2.marginal      0.9024390   1.0000000 0.9997828 0.9066661
# TCAx.parametric.XQ2.joint         0.7689625   0.9994907 0.9006933 0.7412817
# TCAx.parametric.X2Q2.marginal     0.9629630   1.0000000 0.9999176 0.9635843
# TCAx.parametric.X2Q2.joint        0.7742243   0.9992292 0.9085637 0.7495455
# TCA.parametric.full.marginal      0.9024390   0.9999151 0.9997740 0.9025951
# TCA.parametric.full.joint         0.7702866   0.9982014 0.8827529 0.7297044
# TCA.parametric.X2.marginal        0.9736842   1.0000000 0.9999435 0.9739940
# TCA.parametric.X2.joint           0.7718711   0.9979430 0.8879293 0.7339112
# TCA.parametric.Q2.marginal        0.9367089   0.9999159 0.9998599 0.9367140
# TCA.parametric.Q2.joint           0.7825696   0.9994287 0.9002884 0.7508904
# TCA.parametric.XQ2.marginal       0.9638554   1.0000000 0.9999172 0.9644457
# TCA.parametric.XQ2.joint          0.7841601   0.9997199 0.9001208 0.7522246
# TCA.parametric.X2Q2.marginal      0.9600000   0.9999724 0.9999174 0.9600442
# TCA.parametric.X2Q2.joint         0.7750473   0.9994304 0.9009365 0.7458139
# CellDMC.parametric.full.marginal  0.7722772   0.9994067 0.9993509 0.7860364
# CellDMC.parametric.full.joint     0.7959737   0.9964830 0.8936428 0.7535871
# CellDMC.parametric.X2.marginal    0.9662921   1.0000000 0.9999176 0.9668017
# CellDMC.parametric.X2.joint       0.7911290   0.9983832 0.9004612 0.7562306
# Baseline.parametric.full.marginal 0.7434416   0.9992721 0.9236105 0.7342254
# Baseline.parametric.full.joint    0.7627156   0.9950083 0.8451567 0.6954822
# Baseline.parametric.X2.marginal   0.7278863   0.9995443 0.9141159 0.7180511
# Baseline.parametric.X2.joint      0.7815426   0.9954173 0.8571429 0.7164633

# %% [markdown]
# # eval metric

# %%
get_meta_mats = function(bidir_confusion_dfs, key){
    
    meta.mats = list()
    for (method in methods){
        meta.mats[[method]] = matrix(0,length(data.names),length(data.names))
        rownames(meta.mats[[method]]) = data.names
        colnames(meta.mats[[method]]) = data.names
    }

    for (i in 1:length(data.names)){
        for(j in i:length(data.names)){
            #print(paste0(data.names[i],".", data.names[j]))
            bidir_confusion_dfs = bidir_confusion_dfs_list[[paste0(data.names[i],".", data.names[j])]]
            for (method in methods){
                meta.mats[[method]][i,j] = bidir_confusion_dfs$forward[method, key]
                meta.mats[[method]][j,i] = bidir_confusion_dfs$backward[method, key]
            }
        }
    }
    return(meta.mats)
}

# %%
meta.mats.F1 = get_meta_mats(bidir_confusion_dfs, "F1")

# %%
meta.mats.MCC = get_meta_mats(bidir_confusion_dfs, "MCC")

# %%
meta.mats.F1
# Out:
# $TCAx.parametric.full.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8593750 0.8524590 0.8636364
# hannum  0.9512195 1.0000000 0.9487179 0.8979592
# hannon1 0.9879518 0.9230769 1.0000000 0.9642857
# hannon2 0.9714286 0.8437500 0.9600000 1.0000000
#
# $TCAx.parametric.full.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8615543 0.6658668 0.7684391
# hannum  0.7681401 1.0000000 0.5019685 0.6602779
# hannon1 0.3381806 0.2952929 1.0000000 0.9065187
# hannon2 0.3150956 0.2834503 0.6588235 1.0000000
#
# $TCAx.parametric.X2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9285714 0.8807339 0.9090909
# hannum  0.9629630 1.0000000 0.9090909 0.9200000
# hannon1 0.9870130 0.9473684 1.0000000 0.9411765
# hannon2 0.9552239 0.9180328 0.9729730 1.0000000
#
# $TCAx.parametric.X2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8763172 0.6583443 0.7458065
# hannum  0.7742782 1.0000000 0.4880083 0.6449237
# hannon1 0.3613232 0.3225532 1.0000000 0.9057554
# hannon2 0.3091413 0.3064067 0.6747788 1.0000000
#
# $TCAx.parametric.Q2.marginal
#              liu    hannum   hannon1   hannon2
# liu     1.000000 0.9333333 0.9215686 0.8974359
# hannum  0.974359 1.0000000 0.9600000 0.9583333
# hannon1 1.000000 0.9253731 1.0000000 0.9166667
# hannon2 0.937500 0.8571429 0.9230769 1.0000000
#
# $TCAx.parametric.Q2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8779070 0.6738690 0.7566515
# hannum  0.7829246 1.0000000 0.5112060 0.6593407
# hannon1 0.3377432 0.3036893 1.0000000 0.9096652
# hannon2 0.3014671 0.2835785 0.6433647 1.0000000
#
# $TCAx.parametric.XQ2.marginal
#              liu    hannum   hannon1   hannon2
# liu     1.000000 0.9189189 0.9056604 0.8205128
# hannum  0.902439 1.0000000 0.9135802 0.8679245
# hannon1 0.972973 0.9166667 1.0000000 0.9583333
# hannon2 0.937500 0.8928571 0.9393939 1.0000000
#
# $TCAx.parametric.XQ2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8924791 0.6626747 0.7437908
# hannum  0.7689625 1.0000000 0.4871001 0.6248694
# hannon1 0.3439441 0.3064327 1.0000000 0.8923280
# hannon2 0.3067318 0.2944751 0.6708696 1.0000000
#
# $TCAx.parametric.X2Q2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9090909 0.8910891 0.9117647
# hannum  0.9629630 1.0000000 0.9350649 0.9361702
# hannon1 1.0000000 0.9275362 1.0000000 0.9565217
# hannon2 0.9677419 0.9285714 0.9846154 1.0000000
#
# $TCAx.parametric.X2Q2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8916409 0.6617647 0.7489301
# hannum  0.7742243 1.0000000 0.5000000 0.6500868
# hannon1 0.3720491 0.3386792 1.0000000 0.9100318
# hannon2 0.3003310 0.3059319 0.6642617 1.0000000
#
# $TCA.parametric.full.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.6986301 0.8030303 0.8125000
# hannum  0.9024390 1.0000000 0.9487179 0.8936170
# hannon1 0.9500000 0.9066667 1.0000000 0.9615385
# hannon2 0.9859155 0.8666667 0.9428571 1.0000000
#
# $TCA.parametric.full.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8364871 0.6781545 0.7873016
# hannum  0.7702866 1.0000000 0.5009506 0.6682135
# hannon1 0.3422967 0.2876361 1.0000000 0.9006867
# hannon2 0.3285745 0.2962637 0.6659744 1.0000000
#
# $TCA.parametric.X2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9026549 0.9009009 0.9135802
# hannum  0.9736842 1.0000000 0.9487179 0.8800000
# hannon1 0.9866667 0.9600000 1.0000000 0.9787234
# hannon2 0.9855072 0.9508197 0.9859155 1.0000000
#
# $TCA.parametric.X2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8686649 0.6641075 0.7570621
# hannum  0.7718711 1.0000000 0.4919679 0.6448363
# hannon1 0.3689086 0.3234698 1.0000000 0.8950427
# hannon2 0.3199785 0.3138211 0.6708505 1.0000000
#
# $TCA.parametric.Q2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8130081 0.8928571 0.8750000
# hannum  0.9367089 1.0000000 0.9589041 0.9361702
# hannon1 0.9855072 0.9253731 1.0000000 0.9583333
# hannon2 0.8985507 0.8070175 0.9014085 1.0000000
#
# $TCA.parametric.Q2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8704018 0.6888021 0.7821720
# hannum  0.7825696 1.0000000 0.5264249 0.6788247
# hannon1 0.3446043 0.3055255 1.0000000 0.8987758
# hannon2 0.3126177 0.2981993 0.6589398 1.0000000
#
# $TCA.parametric.XQ2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9074074 0.9174312 0.8717949
# hannum  0.9638554 1.0000000 0.9500000 0.9166667
# hannon1 0.9647059 0.9176471 1.0000000 0.9642857
# hannon2 0.9315068 0.8000000 0.9066667 1.0000000
#
# $TCA.parametric.XQ2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8814898 0.6807388 0.7595593
# hannum  0.7841601 1.0000000 0.5144628 0.6580712
# hannon1 0.3592767 0.3174603 1.0000000 0.8909152
# hannon2 0.3152232 0.3018351 0.6686864 1.0000000
#
# $TCA.parametric.X2Q2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.9400000 0.9072165 0.9230769
# hannum  0.9600000 1.0000000 0.9589041 0.9545455
# hannon1 0.9696970 0.9090909 1.0000000 0.9777778
# hannon2 0.9818182 0.9019608 1.0000000 1.0000000
#
# $TCA.parametric.X2Q2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8854680 0.6671470 0.7446809
# hannum  0.7750473 1.0000000 0.5127636 0.6651835
# hannon1 0.3613369 0.3403493 1.0000000 0.9029568
# hannon2 0.2984802 0.3119155 0.6749940 1.0000000
#
# $CellDMC.parametric.full.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.2337165 0.3929825 0.4790419
# hannum  0.7722772 1.0000000 0.9870130 0.9361702
# hannon1 0.8035714 0.9195402 1.0000000 0.9090909
# hannon2 0.8095238 0.8615385 0.9333333 1.0000000
#
# $CellDMC.parametric.full.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.7233065 0.5917603 0.7295539
# hannum  0.7959737 1.0000000 0.4974335 0.6721088
# hannon1 0.3212016 0.2638725 1.0000000 0.9102750
# hannon2 0.3075752 0.2714539 0.6542751 1.0000000
#
# $CellDMC.parametric.X2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8549618 0.8750000 0.8421053
# hannum  0.9662921 1.0000000 0.9534884 0.9285714
# hannon1 1.0000000 0.9534884 1.0000000 0.9696970
# hannon2 0.9565217 0.9032258 0.9736842 1.0000000
#
# $CellDMC.parametric.X2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8545455 0.6133638 0.7222832
# hannum  0.7911290 1.0000000 0.4802343 0.6474609
# hannon1 0.3220647 0.2956204 1.0000000 0.9095907
# hannon2 0.3004105 0.2927543 0.6774008 1.0000000
#
# $Baseline.parametric.full.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8490836 0.6295515 0.7585427
# hannum  0.7434416 1.0000000 0.4938520 0.6595153
# hannon1 0.2579389 0.2413450 1.0000000 0.7781527
# hannon2 0.3001131 0.2984804 0.6247876 1.0000000
#
# $Baseline.parametric.full.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8168729 0.6034241 0.7198917
# hannum  0.7627156 1.0000000 0.4612306 0.6350851
# hannon1 0.3176471 0.2780656 1.0000000 0.8985337
# hannon2 0.3183055 0.2960799 0.6509379 1.0000000
#
# $Baseline.parametric.X2.marginal
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8722521 0.6320615 0.7200000
# hannum  0.7278863 1.0000000 0.5019305 0.5994242
# hannon1 0.2770921 0.2847586 1.0000000 0.8773097
# hannon2 0.2520212 0.2475256 0.6507363 1.0000000
#
# $Baseline.parametric.X2.joint
#               liu    hannum   hannon1   hannon2
# liu     1.0000000 0.8504544 0.6041147 0.6989280
# hannum  0.7815426 1.0000000 0.4679067 0.6147324
# hannon1 0.3263765 0.2906423 1.0000000 0.9063823
# hannon2 0.3211930 0.3126638 0.6846744 1.0000000

# %%
meta.mats = meta.mats.MCC
for (method in methods){
    print(method)
    #print(meta.mats[[method]])
    d = length(data.names)
    print((sum(meta.mats[[method]]) - d)/(d*(d-1)))
}
# Out:
# [1] "TCAx.parametric.full.marginal"
# [1] 0.9211676
# [1] "TCAx.parametric.full.joint"
# [1] 0.5425223
# [1] "TCAx.parametric.X2.marginal"
# [1] 0.9377957
# [1] "TCAx.parametric.X2.joint"
# [1] 0.5606539
# [1] "TCAx.parametric.Q2.marginal"
# [1] 0.9354531
# [1] "TCAx.parametric.Q2.joint"
# [1] 0.550203
# [1] "TCAx.parametric.XQ2.marginal"
# [1] 0.9148608
# [1] "TCAx.parametric.XQ2.joint"
# [1] 0.5529351
# [1] "TCAx.parametric.X2Q2.marginal"
# [1] 0.9439729
# [1] "TCAx.parametric.X2Q2.joint"
# [1] 0.5686353
# [1] "TCA.parametric.full.marginal"
# [1] 0.8948169
# [1] "TCA.parametric.full.joint"
# [1] 0.5333745
# [1] "TCA.parametric.X2.marginal"
# [1] 0.9485311
# [1] "TCA.parametric.X2.joint"
# [1] 0.5535914
# [1] "TCA.parametric.Q2.marginal"
# [1] 0.9104313
# [1] "TCA.parametric.Q2.joint"
# [1] 0.5520744
# [1] "TCA.parametric.XQ2.marginal"
# [1] 0.920528
# [1] "TCA.parametric.XQ2.joint"
# [1] 0.55906
# [1] "TCA.parametric.X2Q2.marginal"
# [1] 0.9499518
# [1] "TCA.parametric.X2Q2.joint"
# [1] 0.5636642
# [1] "CellDMC.parametric.full.marginal"
# [1] 0.7816093
# [1] "CellDMC.parametric.full.joint"
# [1] 0.5005144
# [1] "CellDMC.parametric.X2.marginal"
# [1] 0.9343623
# [1] "CellDMC.parametric.X2.joint"
# [1] 0.535481
# [1] "Baseline.parametric.full.marginal"
# [1] 0.5228604
# [1] "Baseline.parametric.full.joint"
# [1] 0.4519172
# [1] "Baseline.parametric.X2.marginal"
# [1] 0.521789
# [1] "Baseline.parametric.X2.joint"
# [1] 0.4744786

# %%
# [1] "TCAx.parametric.full.marginal"
# [1] 0.9211676
# [1] "TCAx.parametric.full.joint"
# [1] 0.5425223

# [1] "TCAx.parametric.X2.marginal"
# [1] 0.9377957
# [1] "TCAx.parametric.X2.joint"
# [1] 0.5606539

# [1] "TCAx.parametric.X2Q2.marginal"
# [1] 0.9439729
# [1] "TCAx.parametric.X2Q2.joint"
# [1] 0.5686353

# [1] "TCA.parametric.full.marginal"
# [1] 0.8948169
# [1] "TCA.parametric.full.joint"
# [1] 0.5333745


# [1] "CellDMC.parametric.full.marginal"
# [1] 0.7816093
# [1] "CellDMC.parametric.full.joint"
# [1] 0.5005144

# [1] "Baseline.parametric.full.marginal"
# [1] 0.5228604
# [1] "Baseline.parametric.full.joint"
# [1] 0.4519172

# %%
meta.mats = meta.mats.F1
for (method in methods){
    print(method)
    #print(meta.mats[[method]])
    d = length(data.names)
    print((sum(meta.mats[[method]]) - d)/(d*(d-1)))
}
# Out:
# [1] "TCAx.parametric.full.marginal"
# [1] 0.918655
# [1] "TCAx.parametric.full.joint"
# [1] 0.5853007
# [1] "TCAx.parametric.X2.marginal"
# [1] 0.9360198
# [1] "TCAx.parametric.X2.joint"
# [1] 0.5889697
# [1] "TCAx.parametric.Q2.marginal"
# [1] 0.9337325
# [1] "TCAx.parametric.Q2.joint"
# [1] 0.5867839
# [1] "TCAx.parametric.XQ2.marginal"
# [1] 0.91223
# [1] "TCAx.parametric.XQ2.joint"
# [1] 0.5828882
# [1] "TCAx.parametric.X2Q2.marginal"
# [1] 0.9425941
# [1] "TCAx.parametric.X2Q2.joint"
# [1] 0.593161
# [1] "TCA.parametric.full.marginal"
# [1] 0.8893816
# [1] "TCA.parametric.full.joint"
# [1] 0.5885688
# [1] "TCA.parametric.X2.marginal"
# [1] 0.9472642
# [1] "TCA.parametric.X2.joint"
# [1] 0.5908817
# [1] "TCA.parametric.Q2.marginal"
# [1] 0.9074032
# [1] "TCA.parametric.Q2.joint"
# [1] 0.5956548
# [1] "TCA.parametric.XQ2.marginal"
# [1] 0.917664
# [1] "TCA.parametric.XQ2.joint"
# [1] 0.5943233
# [1] "TCA.parametric.X2Q2.marginal"
# [1] 0.948674
# [1] "TCA.parametric.X2Q2.joint"
# [1] 0.5950269
# [1] "CellDMC.parametric.full.marginal"
# [1] 0.75315
# [1] "CellDMC.parametric.full.joint"
# [1] 0.5615658
# [1] "CellDMC.parametric.X2.marginal"
# [1] 0.9314197
# [1] "CellDMC.parametric.X2.joint"
# [1] 0.5755715
# [1] "Baseline.parametric.full.marginal"
# [1] 0.5529004
# [1] "Baseline.parametric.full.joint"
# [1] 0.5632325
# [1] "Baseline.parametric.X2.marginal"
# [1] 0.5535832
# [1] "Baseline.parametric.X2.joint"
# [1] 0.5716343

# %%
# [1] "TCAx.parametric.full.marginal"
# [1] 0.918655
# [1] "TCAx.parametric.full.joint"
# [1] 0.5853007

# [1] "TCAx.parametric.X2.marginal"
# [1] 0.9360198
# [1] "TCAx.parametric.X2.joint"
# [1] 0.5889697

# [1] "TCAx.parametric.X2Q2.marginal"
# [1] 0.9425941
# [1] "TCAx.parametric.X2Q2.joint"
# [1] 0.593161

# [1] "TCA.parametric.full.marginal"
# [1] 0.8893816
# [1] "TCA.parametric.full.joint"
# [1] 0.5885688


#  "CellDMC.parametric.full.marginal"
# [1] 0.75315
# [1] "CellDMC.parametric.full.joint"
# [1] 0.5615658

# %%
saveRDS(bidir_confusion_dfs_list, file.path(results_dir, paste0(pheno,".meta.mats.F1",".rds")))
saveRDS(meta.mats.F1,  file.path(results_dir, paste0(pheno,".meta.mats.F1",".rds")))
saveRDS(meta.mats.MCC, file.path(results_dir, paste0(pheno,".meta.mats.MCC",".rds")))

# %% [markdown]
# # pvalue: how inflated is the unmasked group

# %%
source("visualize.utils.r")
# Out:
# NOTE: Either Arial Narrow or Roboto Condensed fonts are required to use these themes.
#
#       Please use hrbrthemes::import_roboto_condensed() to install Roboto Condensed and
#
#       if Arial Narrow is not on your system, please see https://bit.ly/arialnarrow
#
# Registering fonts with R
#
# hash-2.2.6.2 provided by Decision Patterns
#
#
#
# Attaching package: ‘hash’
#
#
# The following object is masked from ‘package:rlang’:
#
#     hash

# %%
options(repr.plot.width = 24, repr.plot.height = 4, repr.plot.res = 200)
plot_qq_compare_prime(pval.list$liu$TCA.parametric.full.marginal, 
                      pval.list$liu$TCAx.parametric.full.marginal, 
                      experiment = "TCA.full.marginal vs TCAx.full.marginal", 
                      cts = colnames(pval.list$liu$TCAx.parametric.full.marginal))
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title

# %%
options(repr.plot.width = 24, repr.plot.height = 4, repr.plot.res = 200)
plot_qq_compare_prime(pval.list$liu$TCA.parametric.X2.marginal, 
                      pval.list$liu$TCAx.parametric.X2.marginal, 
                      experiment = "TCA.X2.marginal vs TCAx.X2.marginal", 
                      cts = colnames(pval.list$liu$TCAx.parametric.X2.marginal))
# Out:
# plot without title

# %%
plot_qq_compare_prime(pval.list$liu$TCAx.parametric.X2.marginal, 
                      pval.list$liu$TCAx.parametric.full.marginal, 
                      experiment = "TCAx.X2.marginal vs TCAx.full.marginal", 
                      cts = colnames(pval.list$liu$TCAx.parametric.X2.marginal))
# Out:
# plot without title

# %%
plot_qq_compare_prime(pval.list$liu$TCA.parametric.X2.marginal, 
                      pval.list$liu$TCA.parametric.full.marginal, 
                      experiment = "TCA.X2.marginal vs TCA.full.marginal", 
                      cts = colnames(pval.list$liu$TCA.parametric.X2.marginal))
# Out:
# plot without title
